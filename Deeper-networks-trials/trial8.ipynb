# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import seed

seed(1)
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor 

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
df=pd.read_excel('Pre-Processed-Data.xlsx')
df.head()
# Out:
#    Dew Point  Wind Speed  Pressure  Pressure Grad
# 0        4.8        2.47    1029.0             -8
# 1        8.2        7.42    1021.4              0
# 2        6.8        6.81    1021.8             11
# 3        3.6        3.94    1033.7             -1
# 4        6.1        3.33    1033.4            -11

# %%
df.isnull().sum()
# Out:
# Dew Point        0
# Wind Speed       0
# Pressure         0
# Pressure Grad    0
# dtype: int64

# %%
X = df.drop(['Wind Speed'], axis=1)
#Assign the Target column as the output 
Y= df['Wind Speed']

# %%
X_norm=(X-X.min())/(X.max()-X.min())
X_norm
# Out:
#       Dew Point  Pressure  Pressure Grad
# 0      0.487805  0.752055       0.449275
# 1      0.606272  0.647945       0.565217
# 2      0.557491  0.653425       0.724638
# 3      0.445993  0.816438       0.550725
# 4      0.533101  0.812329       0.405797
# ...         ...       ...            ...
# 1091   0.411150  0.706849       0.623188
# 1092   0.470383  0.767123       0.594203
# 1093   0.595819  0.795890       0.594203
# 1094   0.564460  0.831507       0.565217
# 1095   0.581882  0.836986       0.594203
#
# [1096 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X_norm, Y, test_size=0.2, random_state=0)

# %%
model = Sequential()
model.add(Dense(8, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2)) #dropping a few neurons for generalizing the model
model.add(Dense(16, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))   
model.add(Dense(1, activation="linear", kernel_initializer='normal'))
adam = Adam(learning_rate=1e-3, decay=1e-3)

# Compile model
model.compile(loss="mean_squared_error", optimizer='adam', metrics=['mse','mae'])

# %%
print('Fit model...')
filepath="/home/m-marouni/Documents/CE-901/Heathrow/best_weights"
checkpoint = ModelCheckpoint(filepath, monitor='val_mae', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_mae', patience=100, verbose=1, mode='min')
callbacks_list = [checkpoint, early_stopping]

log = model.fit(x_train, y_train,
          validation_split=0.40, batch_size=30, epochs=1000, shuffle=True, callbacks=callbacks_list)
# Out:
# Fit model...
# Epoch 1/1000
# 18/18 [==============================] - 12s 36ms/step - loss: 42.1040 - mse: 42.1040 - mae: 5.9391 - val_loss: 34.2796 - val_mse: 34.2796 - val_mae: 5.3477
#
# Epoch 00001: val_mae improved from inf to 5.34768, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 2/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 36.5990 - mse: 36.5990 - mae: 5.4494 - val_loss: 29.6138 - val_mse: 29.6138 - val_mae: 4.8920
#
# Epoch 00002: val_mae improved from 5.34768 to 4.89203, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 3/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 32.5776 - mse: 32.5776 - mae: 5.0400 - val_loss: 24.7491 - val_mse: 24.7491 - val_mae: 4.3678
#
# Epoch 00003: val_mae improved from 4.89203 to 4.36781, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 4/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 26.7730 - mse: 26.7730 - mae: 4.4653 - val_loss: 20.0883 - val_mse: 20.0883 - val_mae: 3.8012
#
# Epoch 00004: val_mae improved from 4.36781 to 3.80120, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 5/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 21.9806 - mse: 21.9806 - mae: 3.8743 - val_loss: 16.0323 - val_mse: 16.0323 - val_mae: 3.2420
#
# Epoch 00005: val_mae improved from 3.80120 to 3.24198, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 6/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 19.1928 - mse: 19.1928 - mae: 3.4474 - val_loss: 12.9122 - val_mse: 12.9122 - val_mae: 2.7830
#
# Epoch 00006: val_mae improved from 3.24198 to 2.78303, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 7/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 14.3054 - mse: 14.3054 - mae: 2.9300 - val_loss: 10.5924 - val_mse: 10.5924 - val_mae: 2.4578
#
# Epoch 00007: val_mae improved from 2.78303 to 2.45784, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 8/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 12.2174 - mse: 12.2174 - mae: 2.5233 - val_loss: 8.9336 - val_mse: 8.9336 - val_mae: 2.2377
#
# Epoch 00008: val_mae improved from 2.45784 to 2.23770, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 9/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 10.8924 - mse: 10.8924 - mae: 2.3775 - val_loss: 7.7367 - val_mse: 7.7367 - val_mae: 2.0890
#
# Epoch 00009: val_mae improved from 2.23770 to 2.08897, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 10/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 9.5930 - mse: 9.5930 - mae: 2.2082 - val_loss: 6.9037 - val_mse: 6.9037 - val_mae: 1.9954
#
# Epoch 00010: val_mae improved from 2.08897 to 1.99543, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 11/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 8.2352 - mse: 8.2352 - mae: 2.1389 - val_loss: 6.3676 - val_mse: 6.3676 - val_mae: 1.9392
#
# Epoch 00011: val_mae improved from 1.99543 to 1.93916, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 12/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9422 - mse: 6.9422 - mae: 1.9847 - val_loss: 6.0313 - val_mse: 6.0313 - val_mae: 1.9169
#
# Epoch 00012: val_mae improved from 1.93916 to 1.91687, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 13/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4291 - mse: 7.4291 - mae: 2.0621 - val_loss: 5.8256 - val_mse: 5.8256 - val_mae: 1.9122
#
# Epoch 00013: val_mae improved from 1.91687 to 1.91218, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 14/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 7.7849 - mse: 7.7849 - mae: 2.1836 - val_loss: 5.7375 - val_mse: 5.7375 - val_mae: 1.9161
#
# Epoch 00014: val_mae did not improve from 1.91218
# Epoch 15/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.6663 - mse: 7.6663 - mae: 2.1508 - val_loss: 5.6973 - val_mse: 5.6973 - val_mae: 1.9235
#
# Epoch 00015: val_mae did not improve from 1.91218
# Epoch 16/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5276 - mse: 6.5276 - mae: 2.0268 - val_loss: 5.6827 - val_mse: 5.6827 - val_mae: 1.9321
#
# Epoch 00016: val_mae did not improve from 1.91218
# Epoch 17/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2466 - mse: 7.2466 - mae: 2.1171 - val_loss: 5.6843 - val_mse: 5.6843 - val_mae: 1.9391
#
# Epoch 00017: val_mae did not improve from 1.91218
# Epoch 18/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8422 - mse: 6.8422 - mae: 2.0696 - val_loss: 5.6864 - val_mse: 5.6864 - val_mae: 1.9415
#
# Epoch 00018: val_mae did not improve from 1.91218
# Epoch 19/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7140 - mse: 6.7140 - mae: 2.1144 - val_loss: 5.6944 - val_mse: 5.6944 - val_mae: 1.9472
#
# Epoch 00019: val_mae did not improve from 1.91218
# Epoch 20/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7404 - mse: 6.7404 - mae: 2.0382 - val_loss: 5.6999 - val_mse: 5.6999 - val_mae: 1.9501
#
# Epoch 00020: val_mae did not improve from 1.91218
# Epoch 21/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7170 - mse: 6.7170 - mae: 2.0854 - val_loss: 5.7082 - val_mse: 5.7082 - val_mae: 1.9539
#
# Epoch 00021: val_mae did not improve from 1.91218
# Epoch 22/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8994 - mse: 6.8994 - mae: 2.0664 - val_loss: 5.7157 - val_mse: 5.7157 - val_mae: 1.9570
#
# Epoch 00022: val_mae did not improve from 1.91218
# Epoch 23/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9733 - mse: 6.9733 - mae: 2.1185 - val_loss: 5.7236 - val_mse: 5.7236 - val_mae: 1.9600
#
# Epoch 00023: val_mae did not improve from 1.91218
# Epoch 24/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.4332 - mse: 6.4332 - mae: 2.0245 - val_loss: 5.7183 - val_mse: 5.7183 - val_mae: 1.9580
#
# Epoch 00024: val_mae did not improve from 1.91218
# Epoch 25/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 8.3207 - mse: 8.3207 - mae: 2.2701 - val_loss: 5.7250 - val_mse: 5.7250 - val_mae: 1.9606
#
# Epoch 00025: val_mae did not improve from 1.91218
# Epoch 26/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4944 - mse: 7.4944 - mae: 2.2047 - val_loss: 5.7212 - val_mse: 5.7212 - val_mae: 1.9591
#
# Epoch 00026: val_mae did not improve from 1.91218
# Epoch 27/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0931 - mse: 7.0931 - mae: 2.1049 - val_loss: 5.7165 - val_mse: 5.7165 - val_mae: 1.9573
#
# Epoch 00027: val_mae did not improve from 1.91218
# Epoch 28/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.5857 - mse: 6.5857 - mae: 2.0608 - val_loss: 5.7105 - val_mse: 5.7105 - val_mae: 1.9549
#
# Epoch 00028: val_mae did not improve from 1.91218
# Epoch 29/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7043 - mse: 6.7043 - mae: 2.0543 - val_loss: 5.7060 - val_mse: 5.7060 - val_mae: 1.9530
#
# Epoch 00029: val_mae did not improve from 1.91218
# Epoch 30/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7017 - mse: 6.7017 - mae: 2.0479 - val_loss: 5.7169 - val_mse: 5.7169 - val_mae: 1.9575
#
# Epoch 00030: val_mae did not improve from 1.91218
# Epoch 31/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7427 - mse: 6.7427 - mae: 2.0985 - val_loss: 5.7159 - val_mse: 5.7159 - val_mae: 1.9571
#
# Epoch 00031: val_mae did not improve from 1.91218
# Epoch 32/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.5264 - mse: 6.5264 - mae: 2.0188 - val_loss: 5.7124 - val_mse: 5.7124 - val_mae: 1.9557
#
# Epoch 00032: val_mae did not improve from 1.91218
# Epoch 33/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3401 - mse: 6.3401 - mae: 2.0275 - val_loss: 5.7196 - val_mse: 5.7196 - val_mae: 1.9585
#
# Epoch 00033: val_mae did not improve from 1.91218
# Epoch 34/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.5617 - mse: 6.5617 - mae: 2.0659 - val_loss: 5.7190 - val_mse: 5.7190 - val_mae: 1.9583
#
# Epoch 00034: val_mae did not improve from 1.91218
# Epoch 35/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 6.6646 - mse: 6.6646 - mae: 2.0804 - val_loss: 5.7114 - val_mse: 5.7114 - val_mae: 1.9553
#
# Epoch 00035: val_mae did not improve from 1.91218
# Epoch 36/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9524 - mse: 6.9524 - mae: 2.0681 - val_loss: 5.7184 - val_mse: 5.7184 - val_mae: 1.9581
#
# Epoch 00036: val_mae did not improve from 1.91218
# Epoch 37/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.3665 - mse: 7.3665 - mae: 2.1946 - val_loss: 5.7162 - val_mse: 5.7162 - val_mae: 1.9573
#
# Epoch 00037: val_mae did not improve from 1.91218
# Epoch 38/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4000 - mse: 7.4000 - mae: 2.1913 - val_loss: 5.7132 - val_mse: 5.7132 - val_mae: 1.9560
#
# Epoch 00038: val_mae did not improve from 1.91218
# Epoch 39/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3284 - mse: 6.3284 - mae: 2.0021 - val_loss: 5.7183 - val_mse: 5.7183 - val_mae: 1.9581
#
# Epoch 00039: val_mae did not improve from 1.91218
# Epoch 40/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6125 - mse: 6.6125 - mae: 2.0850 - val_loss: 5.7180 - val_mse: 5.7180 - val_mae: 1.9579
#
# Epoch 00040: val_mae did not improve from 1.91218
# Epoch 41/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2421 - mse: 7.2421 - mae: 2.1680 - val_loss: 5.7063 - val_mse: 5.7063 - val_mae: 1.9531
#
# Epoch 00041: val_mae did not improve from 1.91218
# Epoch 42/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1801 - mse: 7.1801 - mae: 2.1067 - val_loss: 5.7099 - val_mse: 5.7099 - val_mae: 1.9547
#
# Epoch 00042: val_mae did not improve from 1.91218
# Epoch 43/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5786 - mse: 6.5786 - mae: 2.0674 - val_loss: 5.6980 - val_mse: 5.6980 - val_mae: 1.9492
#
# Epoch 00043: val_mae did not improve from 1.91218
# Epoch 44/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.5039 - mse: 7.5039 - mae: 2.2292 - val_loss: 5.7019 - val_mse: 5.7019 - val_mae: 1.9511
#
# Epoch 00044: val_mae did not improve from 1.91218
# Epoch 45/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3580 - mse: 6.3580 - mae: 2.0568 - val_loss: 5.7006 - val_mse: 5.7006 - val_mae: 1.9505
#
# Epoch 00045: val_mae did not improve from 1.91218
# Epoch 46/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7037 - mse: 6.7037 - mae: 2.0827 - val_loss: 5.7155 - val_mse: 5.7155 - val_mae: 1.9570
#
# Epoch 00046: val_mae did not improve from 1.91218
# Epoch 47/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7198 - mse: 6.7198 - mae: 2.0479 - val_loss: 5.7163 - val_mse: 5.7163 - val_mae: 1.9573
#
# Epoch 00047: val_mae did not improve from 1.91218
# Epoch 48/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0829 - mse: 7.0829 - mae: 2.1202 - val_loss: 5.7041 - val_mse: 5.7041 - val_mae: 1.9522
#
# Epoch 00048: val_mae did not improve from 1.91218
# Epoch 49/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4896 - mse: 7.4896 - mae: 2.1333 - val_loss: 5.7157 - val_mse: 5.7157 - val_mae: 1.9571
#
# Epoch 00049: val_mae did not improve from 1.91218
# Epoch 50/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9766 - mse: 6.9766 - mae: 2.1215 - val_loss: 5.7034 - val_mse: 5.7034 - val_mae: 1.9518
#
# Epoch 00050: val_mae did not improve from 1.91218
# Epoch 51/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8962 - mse: 6.8962 - mae: 2.0674 - val_loss: 5.7110 - val_mse: 5.7110 - val_mae: 1.9552
#
# Epoch 00051: val_mae did not improve from 1.91218
# Epoch 52/1000
# 18/18 [==============================] - 0s 10ms/step - loss: 7.3668 - mse: 7.3668 - mae: 2.1631 - val_loss: 5.7125 - val_mse: 5.7125 - val_mae: 1.9558
#
# Epoch 00052: val_mae did not improve from 1.91218
# Epoch 53/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1070 - mse: 7.1070 - mae: 2.1335 - val_loss: 5.7214 - val_mse: 5.7215 - val_mae: 1.9593
#
# Epoch 00053: val_mae did not improve from 1.91218
# Epoch 54/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6170 - mse: 6.6170 - mae: 2.0478 - val_loss: 5.7132 - val_mse: 5.7132 - val_mae: 1.9561
#
# Epoch 00054: val_mae did not improve from 1.91218
# Epoch 55/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0905 - mse: 7.0905 - mae: 2.1353 - val_loss: 5.7021 - val_mse: 5.7021 - val_mae: 1.9512
#
# Epoch 00055: val_mae did not improve from 1.91218
# Epoch 56/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8345 - mse: 6.8345 - mae: 2.0796 - val_loss: 5.7115 - val_mse: 5.7115 - val_mae: 1.9554
#
# Epoch 00056: val_mae did not improve from 1.91218
# Epoch 57/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2722 - mse: 7.2722 - mae: 2.1400 - val_loss: 5.7221 - val_mse: 5.7221 - val_mae: 1.9595
#
# Epoch 00057: val_mae did not improve from 1.91218
# Epoch 58/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 7.2488 - mse: 7.2488 - mae: 2.1447 - val_loss: 5.7099 - val_mse: 5.7099 - val_mae: 1.9547
#
# Epoch 00058: val_mae did not improve from 1.91218
# Epoch 59/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1307 - mse: 7.1307 - mae: 2.1837 - val_loss: 5.7159 - val_mse: 5.7159 - val_mae: 1.9572
#
# Epoch 00059: val_mae did not improve from 1.91218
# Epoch 60/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.2884 - mse: 6.2884 - mae: 2.0157 - val_loss: 5.7200 - val_mse: 5.7200 - val_mae: 1.9588
#
# Epoch 00060: val_mae did not improve from 1.91218
# Epoch 61/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9501 - mse: 6.9501 - mae: 2.0950 - val_loss: 5.7020 - val_mse: 5.7020 - val_mae: 1.9512
#
# Epoch 00061: val_mae did not improve from 1.91218
# Epoch 62/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9804 - mse: 6.9804 - mae: 2.0798 - val_loss: 5.7135 - val_mse: 5.7135 - val_mae: 1.9562
#
# Epoch 00062: val_mae did not improve from 1.91218
# Epoch 63/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.4934 - mse: 6.4934 - mae: 2.0200 - val_loss: 5.7327 - val_mse: 5.7327 - val_mae: 1.9635
#
# Epoch 00063: val_mae did not improve from 1.91218
# Epoch 64/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9734 - mse: 6.9734 - mae: 2.0954 - val_loss: 5.7361 - val_mse: 5.7361 - val_mae: 1.9648
#
# Epoch 00064: val_mae did not improve from 1.91218
# Epoch 65/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.7899 - mse: 7.7899 - mae: 2.1434 - val_loss: 5.7200 - val_mse: 5.7200 - val_mae: 1.9588
#
# Epoch 00065: val_mae did not improve from 1.91218
# Epoch 66/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.5888 - mse: 6.5888 - mae: 2.0325 - val_loss: 5.7077 - val_mse: 5.7077 - val_mae: 1.9538
#
# Epoch 00066: val_mae did not improve from 1.91218
# Epoch 67/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3826 - mse: 6.3826 - mae: 2.0399 - val_loss: 5.7027 - val_mse: 5.7027 - val_mae: 1.9515
#
# Epoch 00067: val_mae did not improve from 1.91218
# Epoch 68/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0166 - mse: 7.0166 - mae: 2.0780 - val_loss: 5.7089 - val_mse: 5.7089 - val_mae: 1.9543
#
# Epoch 00068: val_mae did not improve from 1.91218
# Epoch 69/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8321 - mse: 6.8321 - mae: 2.0728 - val_loss: 5.7164 - val_mse: 5.7164 - val_mae: 1.9574
#
# Epoch 00069: val_mae did not improve from 1.91218
# Epoch 70/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8855 - mse: 6.8855 - mae: 2.0941 - val_loss: 5.7166 - val_mse: 5.7166 - val_mae: 1.9575
#
# Epoch 00070: val_mae did not improve from 1.91218
# Epoch 71/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0985 - mse: 7.0985 - mae: 2.1372 - val_loss: 5.7099 - val_mse: 5.7099 - val_mae: 1.9547
#
# Epoch 00071: val_mae did not improve from 1.91218
# Epoch 72/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8500 - mse: 6.8500 - mae: 2.0780 - val_loss: 5.7208 - val_mse: 5.7208 - val_mae: 1.9591
#
# Epoch 00072: val_mae did not improve from 1.91218
# Epoch 73/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1703 - mse: 7.1703 - mae: 2.1173 - val_loss: 5.7231 - val_mse: 5.7231 - val_mae: 1.9599
#
# Epoch 00073: val_mae did not improve from 1.91218
# Epoch 74/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9330 - mse: 6.9330 - mae: 2.0333 - val_loss: 5.7185 - val_mse: 5.7185 - val_mae: 1.9582
#
# Epoch 00074: val_mae did not improve from 1.91218
# Epoch 75/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.5161 - mse: 6.5161 - mae: 2.0190 - val_loss: 5.7207 - val_mse: 5.7207 - val_mae: 1.9590
#
# Epoch 00075: val_mae did not improve from 1.91218
# Epoch 76/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.4821 - mse: 6.4821 - mae: 2.0491 - val_loss: 5.7249 - val_mse: 5.7249 - val_mae: 1.9606
#
# Epoch 00076: val_mae did not improve from 1.91218
# Epoch 77/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.1589 - mse: 7.1589 - mae: 2.1085 - val_loss: 5.7201 - val_mse: 5.7201 - val_mae: 1.9588
#
# Epoch 00077: val_mae did not improve from 1.91218
# Epoch 78/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2909 - mse: 7.2909 - mae: 2.1609 - val_loss: 5.7034 - val_mse: 5.7034 - val_mae: 1.9519
#
# Epoch 00078: val_mae did not improve from 1.91218
# Epoch 79/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0243 - mse: 7.0243 - mae: 2.1127 - val_loss: 5.7039 - val_mse: 5.7039 - val_mae: 1.9521
#
# Epoch 00079: val_mae did not improve from 1.91218
# Epoch 80/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3232 - mse: 6.3232 - mae: 1.9566 - val_loss: 5.7114 - val_mse: 5.7114 - val_mae: 1.9554
#
# Epoch 00080: val_mae did not improve from 1.91218
# Epoch 81/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7162 - mse: 6.7162 - mae: 2.0524 - val_loss: 5.7161 - val_mse: 5.7161 - val_mae: 1.9573
#
# Epoch 00081: val_mae did not improve from 1.91218
# Epoch 82/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1109 - mse: 7.1109 - mae: 2.1392 - val_loss: 5.7196 - val_mse: 5.7196 - val_mae: 1.9587
#
# Epoch 00082: val_mae did not improve from 1.91218
# Epoch 83/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1365 - mse: 7.1365 - mae: 2.1670 - val_loss: 5.7097 - val_mse: 5.7097 - val_mae: 1.9547
#
# Epoch 00083: val_mae did not improve from 1.91218
# Epoch 84/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.3201 - mse: 7.3201 - mae: 2.1282 - val_loss: 5.7100 - val_mse: 5.7100 - val_mae: 1.9548
#
# Epoch 00084: val_mae did not improve from 1.91218
# Epoch 85/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7522 - mse: 6.7522 - mae: 2.0197 - val_loss: 5.6989 - val_mse: 5.6989 - val_mae: 1.9498
#
# Epoch 00085: val_mae did not improve from 1.91218
# Epoch 86/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4669 - mse: 7.4669 - mae: 2.1772 - val_loss: 5.7099 - val_mse: 5.7099 - val_mae: 1.9548
#
# Epoch 00086: val_mae did not improve from 1.91218
# Epoch 87/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0174 - mse: 7.0174 - mae: 2.1446 - val_loss: 5.7045 - val_mse: 5.7045 - val_mae: 1.9524
#
# Epoch 00087: val_mae did not improve from 1.91218
# Epoch 88/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.5333 - mse: 7.5333 - mae: 2.1800 - val_loss: 5.7173 - val_mse: 5.7173 - val_mae: 1.9578
#
# Epoch 00088: val_mae did not improve from 1.91218
# Epoch 89/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0478 - mse: 7.0478 - mae: 2.0663 - val_loss: 5.7104 - val_mse: 5.7104 - val_mae: 1.9550
#
# Epoch 00089: val_mae did not improve from 1.91218
# Epoch 90/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4111 - mse: 7.4111 - mae: 2.1244 - val_loss: 5.7050 - val_mse: 5.7050 - val_mae: 1.9527
#
# Epoch 00090: val_mae did not improve from 1.91218
# Epoch 91/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4607 - mse: 6.4607 - mae: 2.0371 - val_loss: 5.7115 - val_mse: 5.7115 - val_mae: 1.9555
#
# Epoch 00091: val_mae did not improve from 1.91218
# Epoch 92/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6701 - mse: 6.6701 - mae: 2.0737 - val_loss: 5.7071 - val_mse: 5.7071 - val_mae: 1.9536
#
# Epoch 00092: val_mae did not improve from 1.91218
# Epoch 93/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.7785 - mse: 7.7785 - mae: 2.2197 - val_loss: 5.6940 - val_mse: 5.6940 - val_mae: 1.9472
#
# Epoch 00093: val_mae did not improve from 1.91218
# Epoch 94/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.3425 - mse: 7.3425 - mae: 2.1315 - val_loss: 5.6991 - val_mse: 5.6991 - val_mae: 1.9500
#
# Epoch 00094: val_mae did not improve from 1.91218
# Epoch 95/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 5.8587 - mse: 5.8587 - mae: 1.9180 - val_loss: 5.7127 - val_mse: 5.7127 - val_mae: 1.9560
#
# Epoch 00095: val_mae did not improve from 1.91218
# Epoch 96/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2605 - mse: 6.2605 - mae: 2.0388 - val_loss: 5.7183 - val_mse: 5.7183 - val_mae: 1.9582
#
# Epoch 00096: val_mae did not improve from 1.91218
# Epoch 97/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.3542 - mse: 7.3542 - mae: 2.1817 - val_loss: 5.7357 - val_mse: 5.7357 - val_mae: 1.9647
#
# Epoch 00097: val_mae did not improve from 1.91218
# Epoch 98/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 7.2836 - mse: 7.2836 - mae: 2.1289 - val_loss: 5.7255 - val_mse: 5.7255 - val_mae: 1.9609
#
# Epoch 00098: val_mae did not improve from 1.91218
# Epoch 99/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 6.9763 - mse: 6.9763 - mae: 2.1452 - val_loss: 5.7081 - val_mse: 5.7081 - val_mae: 1.9541
#
# Epoch 00099: val_mae did not improve from 1.91218
# Epoch 100/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3935 - mse: 6.3935 - mae: 2.0349 - val_loss: 5.7206 - val_mse: 5.7206 - val_mae: 1.9591
#
# Epoch 00100: val_mae did not improve from 1.91218
# Epoch 101/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 6.4626 - mse: 6.4626 - mae: 2.0607 - val_loss: 5.7171 - val_mse: 5.7171 - val_mae: 1.9578
#
# Epoch 00101: val_mae did not improve from 1.91218
# Epoch 102/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 7.1968 - mse: 7.1968 - mae: 2.1169 - val_loss: 5.7306 - val_mse: 5.7306 - val_mae: 1.9629
#
# Epoch 00102: val_mae did not improve from 1.91218
# Epoch 103/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 6.8642 - mse: 6.8642 - mae: 2.0699 - val_loss: 5.7159 - val_mse: 5.7159 - val_mae: 1.9573
#
# Epoch 00103: val_mae did not improve from 1.91218
# Epoch 104/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 7.7686 - mse: 7.7686 - mae: 2.2248 - val_loss: 5.7121 - val_mse: 5.7121 - val_mae: 1.9558
#
# Epoch 00104: val_mae did not improve from 1.91218
# Epoch 105/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 7.3027 - mse: 7.3027 - mae: 2.1398 - val_loss: 5.7017 - val_mse: 5.7017 - val_mae: 1.9512
#
# Epoch 00105: val_mae did not improve from 1.91218
# Epoch 106/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 7.3411 - mse: 7.3411 - mae: 2.1814 - val_loss: 5.7212 - val_mse: 5.7212 - val_mae: 1.9593
#
# Epoch 00106: val_mae did not improve from 1.91218
# Epoch 107/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 7.3971 - mse: 7.3971 - mae: 2.1659 - val_loss: 5.7141 - val_mse: 5.7141 - val_mae: 1.9566
#
# Epoch 00107: val_mae did not improve from 1.91218
# Epoch 108/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7198 - mse: 6.7198 - mae: 2.0471 - val_loss: 5.7069 - val_mse: 5.7069 - val_mae: 1.9536
#
# Epoch 00108: val_mae did not improve from 1.91218
# Epoch 109/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9400 - mse: 6.9400 - mae: 2.0856 - val_loss: 5.7149 - val_mse: 5.7149 - val_mae: 1.9570
#
# Epoch 00109: val_mae did not improve from 1.91218
# Epoch 110/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7996 - mse: 6.7996 - mae: 2.1296 - val_loss: 5.7064 - val_mse: 5.7064 - val_mae: 1.9534
#
# Epoch 00110: val_mae did not improve from 1.91218
# Epoch 111/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.7536 - mse: 7.7536 - mae: 2.1657 - val_loss: 5.7264 - val_mse: 5.7264 - val_mae: 1.9614
#
# Epoch 00111: val_mae did not improve from 1.91218
# Epoch 112/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2070 - mse: 7.2070 - mae: 2.1013 - val_loss: 5.7049 - val_mse: 5.7049 - val_mae: 1.9528
#
# Epoch 00112: val_mae did not improve from 1.91218
# Epoch 113/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 6.8658 - mse: 6.8658 - mae: 2.0525 - val_loss: 5.7113 - val_mse: 5.7113 - val_mae: 1.9555
#
# Epoch 00113: val_mae did not improve from 1.91218
# Epoch 00113: early stopping

# %%
def show_info(model, X, y, log, weights = None):
    '''
    Show metrics about the evaluation model and plots about loss, rmse and rmspe
    '''
    if (log != None):
        # summarize history for loss
        plt.figure(figsize=(14,10))
        plt.plot(log.history['loss'])
        plt.plot(log.history['val_loss'])
        plt.title('Model Loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MAE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mae'])
        plt.plot(log.history['val_mae'])
        plt.title('Model MAE')
        plt.ylabel('MAE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MSE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mse'])
        plt.plot(log.history['val_mse'])
        plt.title('Model MSE')
        plt.ylabel('MSE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')
    if (weights != None):
        model.load_weights(weights)

    predictions = model.predict(X, verbose=1)

    mse = mean_squared_error(y, predictions)
    mae= mean_absolute_error(y, predictions)

# %%
show_info(model, x_test, y_test, log, weights='/home/m-marouni/Documents/CE-901/Heathrow/best_weights')
# Out:
# 7/7 [==============================] - 0s 1ms/step
