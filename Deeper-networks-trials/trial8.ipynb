# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import seed

seed(1)
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor 

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
df=pd.read_excel('data.xlsx')
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad  Wind Gradient
# 0             128             -8              3
# 1             188              0              8
# 2             265             11              7
# 3             248             -1              2
# 4             224            -11              5

# %%
df['Year']  = df['Date'].apply(lambda x: int(str(x)[:4]))
df['Month'] = df['Date'].apply(lambda x: int(str(x)[5:7]))
df['Day']=df['Date'].apply(lambda x: int(str(x)[8:10]))
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad  Wind Gradient  Year  Month  Day
# 0             128             -8              3  2020      1    1
# 1             188              0              8  2020      1    2
# 2             265             11              7  2020      1    3
# 3             248             -1              2  2020      1    4
# 4             224            -11              5  2020      1    5

# %%
del df['Date']
#del df['Year']
#del df['Month']
df.head()
# Out:
#    Temp  Dew Point  Humidity  Wind Speed  Pressure  Wind Direction  \
# 0   5.7        4.8      94.4        2.47    1029.0             128
# 1   9.3        8.2      92.5        7.42    1021.4             188
# 2   8.2        6.8      91.4        6.81    1021.8             265
# 3   5.6        3.6      87.2        3.94    1033.7             248
# 4   7.8        6.1      89.2        3.33    1033.4             224
#
#    Pressure Grad  Wind Gradient  Year  Month  Day
# 0             -8              3  2020      1    1
# 1              0              8  2020      1    2
# 2             11              7  2020      1    3
# 3             -1              2  2020      1    4
# 4            -11              5  2020      1    5

# %%
X = df.drop(['Wind Speed'], axis=1)
#Assign the Target column as the output 
Y= df['Wind Speed']

# %%
X_norm=(X-X.min())/(X.max()-X.min())
X_norm
# Out:
#           Temp  Dew Point  Humidity  Pressure  Wind Direction  Pressure Grad  \
# 0     0.299639   0.487805  0.923913  0.752055        0.342679       0.449275
# 1     0.429603   0.606272  0.898098  0.647945        0.529595       0.565217
# 2     0.389892   0.557491  0.883152  0.653425        0.769470       0.724638
# 3     0.296029   0.445993  0.826087  0.816438        0.716511       0.550725
# 4     0.375451   0.533101  0.853261  0.812329        0.641745       0.405797
# ...        ...        ...       ...       ...             ...            ...
# 1091  0.198556   0.411150  0.972826  0.706849        0.676012       0.623188
# 1092  0.259928   0.470383  0.966033  0.767123        0.757009       0.594203
# 1093  0.415162   0.595819  0.915761  0.795890        0.738318       0.594203
# 1094  0.346570   0.564460  0.998641  0.831507        0.753894       0.565217
# 1095  0.397112   0.581882  0.913043  0.836986        0.816199       0.594203
#
#       Wind Gradient  Year  Month       Day
# 0          0.200000   1.0    0.0  0.000000
# 1          0.533333   1.0    0.0  0.033333
# 2          0.466667   1.0    0.0  0.066667
# 3          0.133333   1.0    0.0  0.100000
# 4          0.333333   1.0    0.0  0.133333
# ...             ...   ...    ...       ...
# 1091       0.066667   0.0    1.0  0.866667
# 1092       0.200000   0.0    1.0  0.900000
# 1093       0.266667   0.0    1.0  0.933333
# 1094       0.200000   0.0    1.0  0.966667
# 1095       0.200000   0.0    1.0  1.000000
#
# [1096 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X_norm, Y, test_size=0.3, random_state=0)

# %%
model = Sequential()
model.add(Dense(8, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2)) #dropping a few neurons for generalizing the model
model.add(Dense(16, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))   
model.add(Dense(1, activation="linear", kernel_initializer='normal'))
adam = Adam(learning_rate=1e-3, decay=1e-3)

# Compile model
model.compile(loss="mean_squared_error", optimizer='adam', metrics=['mse','mae'])

# %%
print('Fit model...')
filepath="/home/m-marouni/Documents/CE-901/Heathrow/best_weights"
checkpoint = ModelCheckpoint(filepath, monitor='val_mae', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_mae', patience=100, verbose=1, mode='min')
callbacks_list = [checkpoint, early_stopping]

log = model.fit(x_train, y_train,
          validation_split=0.40, batch_size=30, epochs=1000, shuffle=True, callbacks=callbacks_list)
# Out:
# Fit model...
# Epoch 1/1000
# 16/16 [==============================] - 1s 28ms/step - loss: 40.0157 - mse: 40.0157 - mae: 5.7522 - val_loss: 32.7110 - val_mse: 32.7110 - val_mae: 5.1783
#
# Epoch 00001: val_mae improved from inf to 5.17830, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 2/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 36.9898 - mse: 36.9898 - mae: 5.5190 - val_loss: 28.6044 - val_mse: 28.6044 - val_mae: 4.7653
#
# Epoch 00002: val_mae improved from 5.17830 to 4.76531, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 3/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 32.2395 - mse: 32.2395 - mae: 5.0907 - val_loss: 24.2262 - val_mse: 24.2262 - val_mae: 4.2830
#
# Epoch 00003: val_mae improved from 4.76531 to 4.28305, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 4/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 24.5218 - mse: 24.5218 - mae: 4.3338 - val_loss: 19.8326 - val_mse: 19.8326 - val_mae: 3.7401
#
# Epoch 00004: val_mae improved from 4.28305 to 3.74010, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 5/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 22.0461 - mse: 22.0461 - mae: 3.9784 - val_loss: 15.8135 - val_mse: 15.8135 - val_mae: 3.1800
#
# Epoch 00005: val_mae improved from 3.74010 to 3.18002, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 6/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 16.8273 - mse: 16.8273 - mae: 3.3036 - val_loss: 12.6551 - val_mse: 12.6551 - val_mae: 2.7206
#
# Epoch 00006: val_mae improved from 3.18002 to 2.72058, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 7/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 14.3459 - mse: 14.3459 - mae: 2.9292 - val_loss: 10.2789 - val_mse: 10.2789 - val_mae: 2.3973
#
# Epoch 00007: val_mae improved from 2.72058 to 2.39726, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 8/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 11.9054 - mse: 11.9054 - mae: 2.6155 - val_loss: 8.6225 - val_mse: 8.6225 - val_mae: 2.1926
#
# Epoch 00008: val_mae improved from 2.39726 to 2.19258, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 9/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 10.1373 - mse: 10.1373 - mae: 2.3153 - val_loss: 7.5014 - val_mse: 7.5014 - val_mae: 2.0670
#
# Epoch 00009: val_mae improved from 2.19258 to 2.06697, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 10/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 7.8257 - mse: 7.8257 - mae: 1.9451 - val_loss: 6.8274 - val_mse: 6.8274 - val_mae: 1.9993
#
# Epoch 00010: val_mae improved from 2.06697 to 1.99930, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 11/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 7.6480 - mse: 7.6480 - mae: 2.0538 - val_loss: 6.3726 - val_mse: 6.3726 - val_mae: 1.9604
#
# Epoch 00011: val_mae improved from 1.99930 to 1.96041, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 12/1000
# 16/16 [==============================] - 0s 7ms/step - loss: 7.2755 - mse: 7.2755 - mae: 2.0174 - val_loss: 6.1149 - val_mse: 6.1149 - val_mae: 1.9539
#
# Epoch 00012: val_mae improved from 1.96041 to 1.95392, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 13/1000
# 16/16 [==============================] - 0s 7ms/step - loss: 7.2589 - mse: 7.2589 - mae: 2.0124 - val_loss: 5.9830 - val_mse: 5.9830 - val_mae: 1.9546
#
# Epoch 00013: val_mae did not improve from 1.95392
# Epoch 14/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 6.1467 - mse: 6.1467 - mae: 1.8998 - val_loss: 5.9220 - val_mse: 5.9220 - val_mae: 1.9623
#
# Epoch 00014: val_mae did not improve from 1.95392
# Epoch 15/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3239 - mse: 6.3239 - mae: 1.9617 - val_loss: 5.8998 - val_mse: 5.8998 - val_mae: 1.9709
#
# Epoch 00015: val_mae did not improve from 1.95392
# Epoch 16/1000
# 16/16 [==============================] - 0s 8ms/step - loss: 6.6270 - mse: 6.6270 - mae: 2.0010 - val_loss: 5.8970 - val_mse: 5.8970 - val_mae: 1.9808
#
# Epoch 00016: val_mae did not improve from 1.95392
# Epoch 17/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.6319 - mse: 7.6319 - mae: 2.1016 - val_loss: 5.9037 - val_mse: 5.9037 - val_mae: 1.9878
#
# Epoch 00017: val_mae did not improve from 1.95392
# Epoch 18/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 5.6933 - mse: 5.6933 - mae: 1.8674 - val_loss: 5.9107 - val_mse: 5.9107 - val_mae: 1.9920
#
# Epoch 00018: val_mae did not improve from 1.95392
# Epoch 19/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4918 - mse: 7.4918 - mae: 2.1752 - val_loss: 5.9233 - val_mse: 5.9233 - val_mae: 1.9979
#
# Epoch 00019: val_mae did not improve from 1.95392
# Epoch 20/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2995 - mse: 6.2995 - mae: 2.0442 - val_loss: 5.9283 - val_mse: 5.9283 - val_mae: 1.9998
#
# Epoch 00020: val_mae did not improve from 1.95392
# Epoch 21/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.2291 - mse: 7.2291 - mae: 2.1036 - val_loss: 5.9400 - val_mse: 5.9400 - val_mae: 2.0043
#
# Epoch 00021: val_mae did not improve from 1.95392
# Epoch 22/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0620 - mse: 6.0620 - mae: 1.9488 - val_loss: 5.9369 - val_mse: 5.9369 - val_mae: 2.0031
#
# Epoch 00022: val_mae did not improve from 1.95392
# Epoch 23/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0199 - mse: 7.0199 - mae: 2.1070 - val_loss: 5.9576 - val_mse: 5.9576 - val_mae: 2.0103
#
# Epoch 00023: val_mae did not improve from 1.95392
# Epoch 24/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3582 - mse: 6.3582 - mae: 2.0019 - val_loss: 5.9627 - val_mse: 5.9627 - val_mae: 2.0120
#
# Epoch 00024: val_mae did not improve from 1.95392
# Epoch 25/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4984 - mse: 6.4984 - mae: 2.0453 - val_loss: 5.9585 - val_mse: 5.9585 - val_mae: 2.0106
#
# Epoch 00025: val_mae did not improve from 1.95392
# Epoch 26/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9090 - mse: 5.9090 - mae: 1.9558 - val_loss: 5.9660 - val_mse: 5.9660 - val_mae: 2.0130
#
# Epoch 00026: val_mae did not improve from 1.95392
# Epoch 27/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5742 - mse: 6.5742 - mae: 2.0435 - val_loss: 5.9764 - val_mse: 5.9764 - val_mae: 2.0162
#
# Epoch 00027: val_mae did not improve from 1.95392
# Epoch 28/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4686 - mse: 7.4686 - mae: 2.1854 - val_loss: 5.9829 - val_mse: 5.9829 - val_mae: 2.0180
#
# Epoch 00028: val_mae did not improve from 1.95392
# Epoch 29/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0135 - mse: 6.0135 - mae: 1.9396 - val_loss: 5.9799 - val_mse: 5.9799 - val_mae: 2.0172
#
# Epoch 00029: val_mae did not improve from 1.95392
# Epoch 30/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3983 - mse: 6.3983 - mae: 2.0644 - val_loss: 5.9902 - val_mse: 5.9902 - val_mae: 2.0201
#
# Epoch 00030: val_mae did not improve from 1.95392
# Epoch 31/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 7.0984 - mse: 7.0984 - mae: 2.1036 - val_loss: 5.9927 - val_mse: 5.9927 - val_mae: 2.0208
#
# Epoch 00031: val_mae did not improve from 1.95392
# Epoch 32/1000
# 16/16 [==============================] - 0s 7ms/step - loss: 7.3009 - mse: 7.3009 - mae: 2.1294 - val_loss: 5.9709 - val_mse: 5.9709 - val_mae: 2.0145
#
# Epoch 00032: val_mae did not improve from 1.95392
# Epoch 33/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 5.9524 - mse: 5.9524 - mae: 1.9730 - val_loss: 5.9690 - val_mse: 5.9690 - val_mae: 2.0139
#
# Epoch 00033: val_mae did not improve from 1.95392
# Epoch 34/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4082 - mse: 6.4082 - mae: 2.0041 - val_loss: 5.9842 - val_mse: 5.9842 - val_mae: 2.0184
#
# Epoch 00034: val_mae did not improve from 1.95392
# Epoch 35/1000
# 16/16 [==============================] - 0s 7ms/step - loss: 7.0886 - mse: 7.0886 - mae: 2.1247 - val_loss: 5.9857 - val_mse: 5.9857 - val_mae: 2.0188
#
# Epoch 00035: val_mae did not improve from 1.95392
# Epoch 36/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.3893 - mse: 5.3893 - mae: 1.8710 - val_loss: 5.9852 - val_mse: 5.9852 - val_mae: 2.0187
#
# Epoch 00036: val_mae did not improve from 1.95392
# Epoch 37/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5037 - mse: 6.5037 - mae: 1.9994 - val_loss: 5.9908 - val_mse: 5.9908 - val_mae: 2.0203
#
# Epoch 00037: val_mae did not improve from 1.95392
# Epoch 38/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6444 - mse: 6.6444 - mae: 2.0684 - val_loss: 5.9853 - val_mse: 5.9853 - val_mae: 2.0187
#
# Epoch 00038: val_mae did not improve from 1.95392
# Epoch 39/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6574 - mse: 6.6574 - mae: 2.0802 - val_loss: 5.9942 - val_mse: 5.9942 - val_mae: 2.0212
#
# Epoch 00039: val_mae did not improve from 1.95392
# Epoch 40/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0156 - mse: 6.0156 - mae: 1.9494 - val_loss: 5.9849 - val_mse: 5.9849 - val_mae: 2.0186
#
# Epoch 00040: val_mae did not improve from 1.95392
# Epoch 41/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9154 - mse: 6.9154 - mae: 2.1025 - val_loss: 5.9836 - val_mse: 5.9836 - val_mae: 2.0182
#
# Epoch 00041: val_mae did not improve from 1.95392
# Epoch 42/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1191 - mse: 6.1191 - mae: 2.0225 - val_loss: 5.9621 - val_mse: 5.9621 - val_mae: 2.0118
#
# Epoch 00042: val_mae did not improve from 1.95392
# Epoch 43/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3337 - mse: 6.3337 - mae: 1.9893 - val_loss: 5.9853 - val_mse: 5.9853 - val_mae: 2.0187
#
# Epoch 00043: val_mae did not improve from 1.95392
# Epoch 44/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9990 - mse: 6.9990 - mae: 2.0935 - val_loss: 6.0036 - val_mse: 6.0036 - val_mae: 2.0241
#
# Epoch 00044: val_mae did not improve from 1.95392
# Epoch 45/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4833 - mse: 6.4833 - mae: 2.0168 - val_loss: 5.9958 - val_mse: 5.9958 - val_mae: 2.0217
#
# Epoch 00045: val_mae did not improve from 1.95392
# Epoch 46/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 7.0529 - mse: 7.0529 - mae: 2.1349 - val_loss: 5.9830 - val_mse: 5.9830 - val_mae: 2.0181
#
# Epoch 00046: val_mae did not improve from 1.95392
# Epoch 47/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5549 - mse: 6.5549 - mae: 2.0095 - val_loss: 5.9652 - val_mse: 5.9652 - val_mae: 2.0128
#
# Epoch 00047: val_mae did not improve from 1.95392
# Epoch 48/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6700 - mse: 6.6700 - mae: 2.0377 - val_loss: 5.9706 - val_mse: 5.9706 - val_mae: 2.0145
#
# Epoch 00048: val_mae did not improve from 1.95392
# Epoch 49/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8824 - mse: 6.8824 - mae: 2.1238 - val_loss: 5.9686 - val_mse: 5.9686 - val_mae: 2.0138
#
# Epoch 00049: val_mae did not improve from 1.95392
# Epoch 50/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6974 - mse: 6.6974 - mae: 2.0646 - val_loss: 5.9763 - val_mse: 5.9763 - val_mae: 2.0161
#
# Epoch 00050: val_mae did not improve from 1.95392
# Epoch 51/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8172 - mse: 6.8172 - mae: 2.0864 - val_loss: 5.9707 - val_mse: 5.9707 - val_mae: 2.0145
#
# Epoch 00051: val_mae did not improve from 1.95392
# Epoch 52/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.5216 - mse: 7.5216 - mae: 2.1738 - val_loss: 5.9676 - val_mse: 5.9676 - val_mae: 2.0135
#
# Epoch 00052: val_mae did not improve from 1.95392
# Epoch 53/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0094 - mse: 6.0094 - mae: 1.9556 - val_loss: 5.9722 - val_mse: 5.9722 - val_mae: 2.0149
#
# Epoch 00053: val_mae did not improve from 1.95392
# Epoch 54/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6679 - mse: 6.6679 - mae: 2.0249 - val_loss: 5.9794 - val_mse: 5.9794 - val_mae: 2.0171
#
# Epoch 00054: val_mae did not improve from 1.95392
# Epoch 55/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6155 - mse: 6.6155 - mae: 2.0159 - val_loss: 5.9634 - val_mse: 5.9634 - val_mae: 2.0122
#
# Epoch 00055: val_mae did not improve from 1.95392
# Epoch 56/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.8125 - mse: 7.8125 - mae: 2.1848 - val_loss: 5.9762 - val_mse: 5.9762 - val_mae: 2.0161
#
# Epoch 00056: val_mae did not improve from 1.95392
# Epoch 57/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3624 - mse: 6.3624 - mae: 2.0533 - val_loss: 5.9842 - val_mse: 5.9842 - val_mae: 2.0184
#
# Epoch 00057: val_mae did not improve from 1.95392
# Epoch 58/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8946 - mse: 6.8946 - mae: 2.1316 - val_loss: 5.9865 - val_mse: 5.9865 - val_mae: 2.0191
#
# Epoch 00058: val_mae did not improve from 1.95392
# Epoch 59/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5471 - mse: 6.5471 - mae: 2.0444 - val_loss: 6.0051 - val_mse: 6.0051 - val_mae: 2.0246
#
# Epoch 00059: val_mae did not improve from 1.95392
# Epoch 60/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9559 - mse: 6.9559 - mae: 2.1497 - val_loss: 6.0025 - val_mse: 6.0025 - val_mae: 2.0238
#
# Epoch 00060: val_mae did not improve from 1.95392
# Epoch 61/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4529 - mse: 7.4529 - mae: 2.1432 - val_loss: 5.9957 - val_mse: 5.9957 - val_mae: 2.0217
#
# Epoch 00061: val_mae did not improve from 1.95392
# Epoch 62/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0137 - mse: 6.0137 - mae: 1.9700 - val_loss: 5.9678 - val_mse: 5.9678 - val_mae: 2.0136
#
# Epoch 00062: val_mae did not improve from 1.95392
# Epoch 63/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0549 - mse: 7.0549 - mae: 2.1211 - val_loss: 5.9600 - val_mse: 5.9600 - val_mae: 2.0111
#
# Epoch 00063: val_mae did not improve from 1.95392
# Epoch 64/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3194 - mse: 6.3194 - mae: 1.9718 - val_loss: 5.9786 - val_mse: 5.9786 - val_mae: 2.0168
#
# Epoch 00064: val_mae did not improve from 1.95392
# Epoch 65/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 6.5360 - mse: 6.5360 - mae: 2.0365 - val_loss: 5.9678 - val_mse: 5.9678 - val_mae: 2.0136
#
# Epoch 00065: val_mae did not improve from 1.95392
# Epoch 66/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.3042 - mse: 7.3042 - mae: 2.1467 - val_loss: 5.9719 - val_mse: 5.9719 - val_mae: 2.0149
#
# Epoch 00066: val_mae did not improve from 1.95392
# Epoch 67/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3773 - mse: 6.3773 - mae: 1.9913 - val_loss: 5.9615 - val_mse: 5.9615 - val_mae: 2.0116
#
# Epoch 00067: val_mae did not improve from 1.95392
# Epoch 68/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 5.9350 - mse: 5.9350 - mae: 1.9611 - val_loss: 5.9701 - val_mse: 5.9701 - val_mae: 2.0143
#
# Epoch 00068: val_mae did not improve from 1.95392
# Epoch 69/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6468 - mse: 6.6468 - mae: 2.1040 - val_loss: 5.9639 - val_mse: 5.9639 - val_mae: 2.0124
#
# Epoch 00069: val_mae did not improve from 1.95392
# Epoch 70/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6865 - mse: 6.6865 - mae: 2.0443 - val_loss: 5.9948 - val_mse: 5.9948 - val_mae: 2.0214
#
# Epoch 00070: val_mae did not improve from 1.95392
# Epoch 71/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5895 - mse: 6.5895 - mae: 1.9991 - val_loss: 5.9796 - val_mse: 5.9796 - val_mae: 2.0171
#
# Epoch 00071: val_mae did not improve from 1.95392
# Epoch 72/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2849 - mse: 6.2849 - mae: 2.0270 - val_loss: 5.9759 - val_mse: 5.9759 - val_mae: 2.0161
#
# Epoch 00072: val_mae did not improve from 1.95392
# Epoch 73/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5440 - mse: 6.5440 - mae: 2.0471 - val_loss: 5.9976 - val_mse: 5.9976 - val_mae: 2.0222
#
# Epoch 00073: val_mae did not improve from 1.95392
# Epoch 74/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0083 - mse: 6.0083 - mae: 1.9651 - val_loss: 5.9682 - val_mse: 5.9682 - val_mae: 2.0138
#
# Epoch 00074: val_mae did not improve from 1.95392
# Epoch 75/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0230 - mse: 7.0230 - mae: 2.1335 - val_loss: 5.9807 - val_mse: 5.9807 - val_mae: 2.0174
#
# Epoch 00075: val_mae did not improve from 1.95392
# Epoch 76/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0815 - mse: 6.0815 - mae: 1.9402 - val_loss: 5.9970 - val_mse: 5.9970 - val_mae: 2.0220
#
# Epoch 00076: val_mae did not improve from 1.95392
# Epoch 77/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2229 - mse: 7.2229 - mae: 2.1338 - val_loss: 5.9641 - val_mse: 5.9641 - val_mae: 2.0125
#
# Epoch 00077: val_mae did not improve from 1.95392
# Epoch 78/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.0262 - mse: 6.0262 - mae: 1.9455 - val_loss: 5.9713 - val_mse: 5.9713 - val_mae: 2.0147
#
# Epoch 00078: val_mae did not improve from 1.95392
# Epoch 79/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6622 - mse: 6.6622 - mae: 2.0208 - val_loss: 5.9795 - val_mse: 5.9795 - val_mae: 2.0171
#
# Epoch 00079: val_mae did not improve from 1.95392
# Epoch 80/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4789 - mse: 6.4789 - mae: 2.0037 - val_loss: 5.9820 - val_mse: 5.9820 - val_mae: 2.0178
#
# Epoch 00080: val_mae did not improve from 1.95392
# Epoch 81/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9991 - mse: 6.9991 - mae: 2.0676 - val_loss: 5.9754 - val_mse: 5.9754 - val_mae: 2.0159
#
# Epoch 00081: val_mae did not improve from 1.95392
# Epoch 82/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8579 - mse: 6.8579 - mae: 2.0886 - val_loss: 5.9726 - val_mse: 5.9726 - val_mae: 2.0151
#
# Epoch 00082: val_mae did not improve from 1.95392
# Epoch 83/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2419 - mse: 6.2419 - mae: 1.9978 - val_loss: 5.9566 - val_mse: 5.9566 - val_mae: 2.0100
#
# Epoch 00083: val_mae did not improve from 1.95392
# Epoch 84/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0734 - mse: 7.0734 - mae: 2.1427 - val_loss: 5.9716 - val_mse: 5.9716 - val_mae: 2.0148
#
# Epoch 00084: val_mae did not improve from 1.95392
# Epoch 85/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9439 - mse: 6.9439 - mae: 2.0123 - val_loss: 5.9809 - val_mse: 5.9809 - val_mae: 2.0175
#
# Epoch 00085: val_mae did not improve from 1.95392
# Epoch 86/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2031 - mse: 6.2031 - mae: 2.0197 - val_loss: 5.9657 - val_mse: 5.9657 - val_mae: 2.0130
#
# Epoch 00086: val_mae did not improve from 1.95392
# Epoch 87/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.4602 - mse: 7.4602 - mae: 2.0916 - val_loss: 5.9698 - val_mse: 5.9698 - val_mae: 2.0143
#
# Epoch 00087: val_mae did not improve from 1.95392
# Epoch 88/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 5.8311 - mse: 5.8311 - mae: 1.9604 - val_loss: 5.9536 - val_mse: 5.9536 - val_mae: 2.0090
#
# Epoch 00088: val_mae did not improve from 1.95392
# Epoch 89/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.1177 - mse: 7.1177 - mae: 2.1538 - val_loss: 5.9866 - val_mse: 5.9866 - val_mae: 2.0192
#
# Epoch 00089: val_mae did not improve from 1.95392
# Epoch 90/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9976 - mse: 6.9976 - mae: 2.0875 - val_loss: 6.0095 - val_mse: 6.0095 - val_mae: 2.0260
#
# Epoch 00090: val_mae did not improve from 1.95392
# Epoch 91/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7198 - mse: 6.7198 - mae: 2.0702 - val_loss: 6.0029 - val_mse: 6.0029 - val_mae: 2.0239
#
# Epoch 00091: val_mae did not improve from 1.95392
# Epoch 92/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.4659 - mse: 7.4659 - mae: 2.1573 - val_loss: 5.9792 - val_mse: 5.9792 - val_mae: 2.0170
#
# Epoch 00092: val_mae did not improve from 1.95392
# Epoch 93/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8408 - mse: 6.8408 - mae: 2.0365 - val_loss: 5.9756 - val_mse: 5.9756 - val_mae: 2.0160
#
# Epoch 00093: val_mae did not improve from 1.95392
# Epoch 94/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.3556 - mse: 7.3556 - mae: 2.1616 - val_loss: 5.9790 - val_mse: 5.9790 - val_mae: 2.0170
#
# Epoch 00094: val_mae did not improve from 1.95392
# Epoch 95/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.7017 - mse: 5.7017 - mae: 1.9215 - val_loss: 5.9679 - val_mse: 5.9679 - val_mae: 2.0137
#
# Epoch 00095: val_mae did not improve from 1.95392
# Epoch 96/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8428 - mse: 6.8428 - mae: 2.1178 - val_loss: 5.9849 - val_mse: 5.9849 - val_mae: 2.0187
#
# Epoch 00096: val_mae did not improve from 1.95392
# Epoch 97/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 5.9526 - mse: 5.9526 - mae: 2.0038 - val_loss: 5.9699 - val_mse: 5.9699 - val_mae: 2.0143
#
# Epoch 00097: val_mae did not improve from 1.95392
# Epoch 98/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3083 - mse: 6.3083 - mae: 1.9758 - val_loss: 5.9803 - val_mse: 5.9803 - val_mae: 2.0174
#
# Epoch 00098: val_mae did not improve from 1.95392
# Epoch 99/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4422 - mse: 6.4422 - mae: 2.0332 - val_loss: 5.9788 - val_mse: 5.9788 - val_mae: 2.0170
#
# Epoch 00099: val_mae did not improve from 1.95392
# Epoch 100/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6451 - mse: 6.6451 - mae: 2.0796 - val_loss: 5.9621 - val_mse: 5.9621 - val_mae: 2.0119
#
# Epoch 00100: val_mae did not improve from 1.95392
# Epoch 101/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.4597 - mse: 7.4597 - mae: 2.1716 - val_loss: 5.9895 - val_mse: 5.9895 - val_mae: 2.0200
#
# Epoch 00101: val_mae did not improve from 1.95392
# Epoch 102/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3773 - mse: 6.3773 - mae: 2.0226 - val_loss: 5.9691 - val_mse: 5.9691 - val_mae: 2.0141
#
# Epoch 00102: val_mae did not improve from 1.95392
# Epoch 103/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3226 - mse: 6.3226 - mae: 2.0052 - val_loss: 5.9789 - val_mse: 5.9789 - val_mae: 2.0170
#
# Epoch 00103: val_mae did not improve from 1.95392
# Epoch 104/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7223 - mse: 6.7223 - mae: 2.0778 - val_loss: 5.9739 - val_mse: 5.9739 - val_mae: 2.0155
#
# Epoch 00104: val_mae did not improve from 1.95392
# Epoch 105/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6826 - mse: 6.6826 - mae: 2.0947 - val_loss: 5.9805 - val_mse: 5.9805 - val_mae: 2.0174
#
# Epoch 00105: val_mae did not improve from 1.95392
# Epoch 106/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2711 - mse: 7.2711 - mae: 2.1397 - val_loss: 5.9873 - val_mse: 5.9873 - val_mae: 2.0194
#
# Epoch 00106: val_mae did not improve from 1.95392
# Epoch 107/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.4900 - mse: 7.4900 - mae: 2.1293 - val_loss: 5.9760 - val_mse: 5.9760 - val_mae: 2.0162
#
# Epoch 00107: val_mae did not improve from 1.95392
# Epoch 108/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5983 - mse: 6.5983 - mae: 2.0471 - val_loss: 5.9713 - val_mse: 5.9713 - val_mae: 2.0148
#
# Epoch 00108: val_mae did not improve from 1.95392
# Epoch 109/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0711 - mse: 6.0711 - mae: 1.9887 - val_loss: 5.9581 - val_mse: 5.9581 - val_mae: 2.0106
#
# Epoch 00109: val_mae did not improve from 1.95392
# Epoch 110/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9466 - mse: 6.9466 - mae: 2.0681 - val_loss: 6.0092 - val_mse: 6.0092 - val_mae: 2.0259
#
# Epoch 00110: val_mae did not improve from 1.95392
# Epoch 111/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0151 - mse: 6.0151 - mae: 1.9863 - val_loss: 5.9754 - val_mse: 5.9754 - val_mae: 2.0160
#
# Epoch 00111: val_mae did not improve from 1.95392
# Epoch 112/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2089 - mse: 7.2089 - mae: 2.0988 - val_loss: 5.9773 - val_mse: 5.9773 - val_mae: 2.0166
#
# Epoch 00112: val_mae did not improve from 1.95392
# Epoch 00112: early stopping

# %%
def show_info(model, X, y, log, weights = None):
    '''
    Show metrics about the evaluation model and plots about loss, rmse and rmspe
    '''
    if (log != None):
        # summarize history for loss
        plt.figure(figsize=(14,10))
        plt.plot(log.history['loss'])
        plt.plot(log.history['val_loss'])
        plt.title('Model Loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MAE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mae'])
        plt.plot(log.history['val_mae'])
        plt.title('Model MAE')
        plt.ylabel('MAE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MSE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mse'])
        plt.plot(log.history['val_mse'])
        plt.title('Model MSE')
        plt.ylabel('MSE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')
    if (weights != None):
        model.load_weights(weights)

    predictions = model.predict(X, verbose=1)

    mse = mean_squared_error(y, predictions)
    mae= mean_absolute_error(y, predictions)

# %%
show_info(model, x_test, y_test, log, weights='/home/m-marouni/Documents/CE-901/Heathrow/best_weights')
# Out:
# 11/11 [==============================] - 0s 1ms/step
