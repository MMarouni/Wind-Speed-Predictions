# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import seed

seed(1)
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor 

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
df=pd.read_excel('Preprocessed-data.xlsx')
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad  Wind Gradient
# 0             128             -8              3
# 1             188              0              8
# 2             265             11              7
# 3             248             -1              2
# 4             224            -11              5

# %%
df.isnull().sum()
# Out:
# Date              0
# Temp              0
# Dew Point         0
# Humidity          0
# Wind Speed        0
# Pressure          0
# Wind Direction    0
# Pressure Grad     0
# Wind Gradient     0
# dtype: int64

# %%
df['Year']  = df['Date'].apply(lambda x: int(str(x)[:4]))
df['Month'] = df['Date'].apply(lambda x: int(str(x)[5:7]))
df['Day']=df['Date'].apply(lambda x: int(str(x)[8:10]))
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad  Wind Gradient  Year  Month  Day
# 0             128             -8              3  2020      1    1
# 1             188              0              8  2020      1    2
# 2             265             11              7  2020      1    3
# 3             248             -1              2  2020      1    4
# 4             224            -11              5  2020      1    5

# %%
del df['Date']
#del df['Year']
#del df['Month']
df.head()
# Out:
#    Temp  Dew Point  Humidity  Wind Speed  Pressure  Wind Direction  \
# 0   5.7        4.8      94.4        2.47    1029.0             128
# 1   9.3        8.2      92.5        7.42    1021.4             188
# 2   8.2        6.8      91.4        6.81    1021.8             265
# 3   5.6        3.6      87.2        3.94    1033.7             248
# 4   7.8        6.1      89.2        3.33    1033.4             224
#
#    Pressure Grad  Wind Gradient  Year  Month  Day
# 0             -8              3  2020      1    1
# 1              0              8  2020      1    2
# 2             11              7  2020      1    3
# 3             -1              2  2020      1    4
# 4            -11              5  2020      1    5

# %%
X = df.drop(['Wind Speed'], axis=1)
#Assign the Target column as the output 
Y= df['Wind Speed']

# %%
X_norm=(X-X.min())/(X.max()-X.min())
X_norm
# Out:
#           Temp  Dew Point  Humidity  Pressure  Wind Direction  Pressure Grad  \
# 0     0.299639   0.487805  0.923913  0.752055        0.342679       0.449275
# 1     0.429603   0.606272  0.898098  0.647945        0.529595       0.565217
# 2     0.389892   0.557491  0.883152  0.653425        0.769470       0.724638
# 3     0.296029   0.445993  0.826087  0.816438        0.716511       0.550725
# 4     0.375451   0.533101  0.853261  0.812329        0.641745       0.405797
# ...        ...        ...       ...       ...             ...            ...
# 1091  0.198556   0.411150  0.972826  0.706849        0.676012       0.623188
# 1092  0.259928   0.470383  0.966033  0.767123        0.757009       0.594203
# 1093  0.415162   0.595819  0.915761  0.795890        0.738318       0.594203
# 1094  0.346570   0.564460  0.998641  0.831507        0.753894       0.565217
# 1095  0.397112   0.581882  0.913043  0.836986        0.816199       0.594203
#
#       Wind Gradient  Year  Month       Day
# 0          0.200000   1.0    0.0  0.000000
# 1          0.533333   1.0    0.0  0.033333
# 2          0.466667   1.0    0.0  0.066667
# 3          0.133333   1.0    0.0  0.100000
# 4          0.333333   1.0    0.0  0.133333
# ...             ...   ...    ...       ...
# 1091       0.066667   0.0    1.0  0.866667
# 1092       0.200000   0.0    1.0  0.900000
# 1093       0.266667   0.0    1.0  0.933333
# 1094       0.200000   0.0    1.0  0.966667
# 1095       0.200000   0.0    1.0  1.000000
#
# [1096 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X_norm, Y, test_size=0.3, random_state=0)

# %%
model = Sequential()
model.add(Dense(8, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2)) #dropping a few neurons for generalizing the model
model.add(Dense(16, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))   
model.add(Dense(1, activation="linear", kernel_initializer='normal'))
adam = Adam(learning_rate=1e-3, decay=1e-3)

# Compile model
model.compile(loss="mean_squared_error", optimizer='adam', metrics=['mse','mae'])

# %%
print('Fit model...')
filepath="/home/m-marouni/Documents/CE-901/Heathrow/best_weights"
checkpoint = ModelCheckpoint(filepath, monitor='val_mae', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_mae', patience=100, verbose=1, mode='min')
callbacks_list = [checkpoint, early_stopping]

log = model.fit(x_train, y_train,
          validation_split=0.40, batch_size=30, epochs=1000, shuffle=True, callbacks=callbacks_list)
# Out:
# Fit model...
# Epoch 1/1000
# 16/16 [==============================] - 10s 33ms/step - loss: 42.0107 - mse: 42.0107 - mae: 5.9291 - val_loss: 34.5733 - val_mse: 34.5733 - val_mae: 5.3558
#
# Epoch 00001: val_mae improved from inf to 5.35576, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 2/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 38.8134 - mse: 38.8134 - mae: 5.6890 - val_loss: 30.4518 - val_mse: 30.4518 - val_mae: 4.9561
#
# Epoch 00002: val_mae improved from 5.35576 to 4.95608, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 3/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 34.4019 - mse: 34.4019 - mae: 5.3081 - val_loss: 26.1761 - val_mse: 26.1761 - val_mae: 4.5043
#
# Epoch 00003: val_mae improved from 4.95608 to 4.50434, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 4/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 26.7140 - mse: 26.7140 - mae: 4.5867 - val_loss: 21.9420 - val_mse: 21.9420 - val_mae: 4.0101
#
# Epoch 00004: val_mae improved from 4.50434 to 4.01009, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 5/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 24.4410 - mse: 24.4410 - mae: 4.2732 - val_loss: 18.0379 - val_mse: 18.0379 - val_mae: 3.4987
#
# Epoch 00005: val_mae improved from 4.01009 to 3.49865, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 6/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 19.0209 - mse: 19.0209 - mae: 3.6174 - val_loss: 14.8347 - val_mse: 14.8347 - val_mae: 3.0368
#
# Epoch 00006: val_mae improved from 3.49865 to 3.03681, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 7/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 16.6695 - mse: 16.6695 - mae: 3.2806 - val_loss: 12.2731 - val_mse: 12.2731 - val_mae: 2.6681
#
# Epoch 00007: val_mae improved from 3.03681 to 2.66810, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 8/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 13.9855 - mse: 13.9855 - mae: 2.9250 - val_loss: 10.3393 - val_mse: 10.3393 - val_mae: 2.4053
#
# Epoch 00008: val_mae improved from 2.66810 to 2.40532, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 9/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 12.0450 - mse: 12.0450 - mae: 2.5675 - val_loss: 8.8846 - val_mse: 8.8846 - val_mae: 2.2227
#
# Epoch 00009: val_mae improved from 2.40532 to 2.22265, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 10/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 9.2390 - mse: 9.2390 - mae: 2.1373 - val_loss: 7.8669 - val_mse: 7.8669 - val_mae: 2.1053
#
# Epoch 00010: val_mae improved from 2.22265 to 2.10533, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 11/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 8.7488 - mse: 8.7488 - mae: 2.2011 - val_loss: 7.0906 - val_mse: 7.0906 - val_mae: 2.0245
#
# Epoch 00011: val_mae improved from 2.10533 to 2.02451, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 12/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 8.1487 - mse: 8.1487 - mae: 2.0889 - val_loss: 6.5647 - val_mse: 6.5647 - val_mae: 1.9734
#
# Epoch 00012: val_mae improved from 2.02451 to 1.97343, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 13/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.6958 - mse: 7.6958 - mae: 1.9999 - val_loss: 6.2397 - val_mse: 6.2397 - val_mae: 1.9539
#
# Epoch 00013: val_mae improved from 1.97343 to 1.95391, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 14/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2997 - mse: 6.2997 - mae: 1.9080 - val_loss: 6.0489 - val_mse: 6.0489 - val_mae: 1.9507
#
# Epoch 00014: val_mae improved from 1.95391 to 1.95075, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 15/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2789 - mse: 6.2789 - mae: 1.9230 - val_loss: 5.9487 - val_mse: 5.9487 - val_mae: 1.9534
#
# Epoch 00015: val_mae did not improve from 1.95075
# Epoch 16/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6433 - mse: 6.6433 - mae: 1.9800 - val_loss: 5.9009 - val_mse: 5.9009 - val_mae: 1.9623
#
# Epoch 00016: val_mae did not improve from 1.95075
# Epoch 17/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.5487 - mse: 7.5487 - mae: 2.0500 - val_loss: 5.8891 - val_mse: 5.8891 - val_mae: 1.9711
#
# Epoch 00017: val_mae did not improve from 1.95075
# Epoch 18/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.6776 - mse: 5.6776 - mae: 1.8366 - val_loss: 5.8918 - val_mse: 5.8918 - val_mae: 1.9782
#
# Epoch 00018: val_mae did not improve from 1.95075
# Epoch 19/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.3764 - mse: 7.3764 - mae: 2.1407 - val_loss: 5.9030 - val_mse: 5.9030 - val_mae: 1.9859
#
# Epoch 00019: val_mae did not improve from 1.95075
# Epoch 20/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.1997 - mse: 6.1997 - mae: 2.0176 - val_loss: 5.9118 - val_mse: 5.9118 - val_mae: 1.9900
#
# Epoch 00020: val_mae did not improve from 1.95075
# Epoch 21/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.3693 - mse: 7.3693 - mae: 2.1173 - val_loss: 5.9272 - val_mse: 5.9272 - val_mae: 1.9961
#
# Epoch 00021: val_mae did not improve from 1.95075
# Epoch 22/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9368 - mse: 5.9368 - mae: 1.9263 - val_loss: 5.9287 - val_mse: 5.9287 - val_mae: 1.9967
#
# Epoch 00022: val_mae did not improve from 1.95075
# Epoch 23/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.8612 - mse: 6.8612 - mae: 2.0709 - val_loss: 5.9507 - val_mse: 5.9507 - val_mae: 2.0046
#
# Epoch 00023: val_mae did not improve from 1.95075
# Epoch 24/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.3197 - mse: 6.3197 - mae: 2.0061 - val_loss: 5.9553 - val_mse: 5.9553 - val_mae: 2.0061
#
# Epoch 00024: val_mae did not improve from 1.95075
# Epoch 25/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.3049 - mse: 6.3049 - mae: 2.0037 - val_loss: 5.9554 - val_mse: 5.9554 - val_mae: 2.0062
#
# Epoch 00025: val_mae did not improve from 1.95075
# Epoch 26/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9695 - mse: 5.9695 - mae: 1.9541 - val_loss: 5.9651 - val_mse: 5.9651 - val_mae: 2.0093
#
# Epoch 00026: val_mae did not improve from 1.95075
# Epoch 27/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4552 - mse: 6.4552 - mae: 2.0159 - val_loss: 5.9780 - val_mse: 5.9780 - val_mae: 2.0132
#
# Epoch 00027: val_mae did not improve from 1.95075
# Epoch 28/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.3921 - mse: 7.3921 - mae: 2.1559 - val_loss: 5.9848 - val_mse: 5.9848 - val_mae: 2.0152
#
# Epoch 00028: val_mae did not improve from 1.95075
# Epoch 29/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9544 - mse: 5.9544 - mae: 1.9257 - val_loss: 5.9815 - val_mse: 5.9815 - val_mae: 2.0142
#
# Epoch 00029: val_mae did not improve from 1.95075
# Epoch 30/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.3750 - mse: 6.3750 - mae: 2.0514 - val_loss: 5.9878 - val_mse: 5.9878 - val_mae: 2.0160
#
# Epoch 00030: val_mae did not improve from 1.95075
# Epoch 31/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9766 - mse: 6.9766 - mae: 2.0690 - val_loss: 5.9903 - val_mse: 5.9903 - val_mae: 2.0168
#
# Epoch 00031: val_mae did not improve from 1.95075
# Epoch 32/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.2521 - mse: 7.2521 - mae: 2.1123 - val_loss: 5.9667 - val_mse: 5.9667 - val_mae: 2.0098
#
# Epoch 00032: val_mae did not improve from 1.95075
# Epoch 33/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9792 - mse: 5.9792 - mae: 1.9769 - val_loss: 5.9632 - val_mse: 5.9632 - val_mae: 2.0087
#
# Epoch 00033: val_mae did not improve from 1.95075
# Epoch 34/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4481 - mse: 6.4481 - mae: 2.0056 - val_loss: 5.9748 - val_mse: 5.9748 - val_mae: 2.0122
#
# Epoch 00034: val_mae did not improve from 1.95075
# Epoch 35/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.0307 - mse: 7.0307 - mae: 2.1011 - val_loss: 5.9788 - val_mse: 5.9788 - val_mae: 2.0134
#
# Epoch 00035: val_mae did not improve from 1.95075
# Epoch 36/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.2882 - mse: 5.2882 - mae: 1.8514 - val_loss: 5.9809 - val_mse: 5.9809 - val_mae: 2.0141
#
# Epoch 00036: val_mae did not improve from 1.95075
# Epoch 37/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4210 - mse: 6.4210 - mae: 1.9869 - val_loss: 5.9877 - val_mse: 5.9877 - val_mae: 2.0160
#
# Epoch 00037: val_mae did not improve from 1.95075
# Epoch 38/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6430 - mse: 6.6430 - mae: 2.0681 - val_loss: 5.9806 - val_mse: 5.9806 - val_mae: 2.0139
#
# Epoch 00038: val_mae did not improve from 1.95075
# Epoch 39/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6181 - mse: 6.6181 - mae: 2.0653 - val_loss: 5.9849 - val_mse: 5.9849 - val_mae: 2.0152
#
# Epoch 00039: val_mae did not improve from 1.95075
# Epoch 40/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9741 - mse: 5.9741 - mae: 1.9201 - val_loss: 5.9798 - val_mse: 5.9798 - val_mae: 2.0137
#
# Epoch 00040: val_mae did not improve from 1.95075
# Epoch 41/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.7820 - mse: 6.7820 - mae: 2.0746 - val_loss: 5.9784 - val_mse: 5.9784 - val_mae: 2.0133
#
# Epoch 00041: val_mae did not improve from 1.95075
# Epoch 42/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.1174 - mse: 6.1174 - mae: 2.0120 - val_loss: 5.9582 - val_mse: 5.9582 - val_mae: 2.0071
#
# Epoch 00042: val_mae did not improve from 1.95075
# Epoch 43/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4207 - mse: 6.4207 - mae: 2.0023 - val_loss: 5.9837 - val_mse: 5.9837 - val_mae: 2.0149
#
# Epoch 00043: val_mae did not improve from 1.95075
# Epoch 44/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9672 - mse: 6.9672 - mae: 2.0920 - val_loss: 6.0077 - val_mse: 6.0077 - val_mae: 2.0222
#
# Epoch 00044: val_mae did not improve from 1.95075
# Epoch 45/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4544 - mse: 6.4544 - mae: 2.0100 - val_loss: 5.9995 - val_mse: 5.9995 - val_mae: 2.0197
#
# Epoch 00045: val_mae did not improve from 1.95075
# Epoch 46/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0107 - mse: 7.0107 - mae: 2.1263 - val_loss: 5.9813 - val_mse: 5.9813 - val_mae: 2.0142
#
# Epoch 00046: val_mae did not improve from 1.95075
# Epoch 47/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4958 - mse: 6.4958 - mae: 2.0145 - val_loss: 5.9563 - val_mse: 5.9563 - val_mae: 2.0065
#
# Epoch 00047: val_mae did not improve from 1.95075
# Epoch 48/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6298 - mse: 6.6298 - mae: 2.0323 - val_loss: 5.9616 - val_mse: 5.9616 - val_mae: 2.0082
#
# Epoch 00048: val_mae did not improve from 1.95075
# Epoch 49/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.7252 - mse: 6.7252 - mae: 2.0758 - val_loss: 5.9634 - val_mse: 5.9634 - val_mae: 2.0088
#
# Epoch 00049: val_mae did not improve from 1.95075
# Epoch 50/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6516 - mse: 6.6516 - mae: 2.0498 - val_loss: 5.9751 - val_mse: 5.9751 - val_mae: 2.0124
#
# Epoch 00050: val_mae did not improve from 1.95075
# Epoch 51/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6356 - mse: 6.6356 - mae: 2.0464 - val_loss: 5.9655 - val_mse: 5.9655 - val_mae: 2.0095
#
# Epoch 00051: val_mae did not improve from 1.95075
# Epoch 52/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.6022 - mse: 7.6022 - mae: 2.1812 - val_loss: 5.9618 - val_mse: 5.9618 - val_mae: 2.0083
#
# Epoch 00052: val_mae did not improve from 1.95075
# Epoch 53/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.8564 - mse: 5.8564 - mae: 1.9283 - val_loss: 5.9650 - val_mse: 5.9650 - val_mae: 2.0093
#
# Epoch 00053: val_mae did not improve from 1.95075
# Epoch 54/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6340 - mse: 6.6340 - mae: 2.0086 - val_loss: 5.9758 - val_mse: 5.9758 - val_mae: 2.0126
#
# Epoch 00054: val_mae did not improve from 1.95075
# Epoch 55/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4358 - mse: 6.4358 - mae: 1.9804 - val_loss: 5.9643 - val_mse: 5.9643 - val_mae: 2.0091
#
# Epoch 00055: val_mae did not improve from 1.95075
# Epoch 56/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.4556 - mse: 7.4556 - mae: 2.1277 - val_loss: 5.9774 - val_mse: 5.9774 - val_mae: 2.0130
#
# Epoch 00056: val_mae did not improve from 1.95075
# Epoch 57/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.1772 - mse: 6.1772 - mae: 2.0166 - val_loss: 5.9829 - val_mse: 5.9829 - val_mae: 2.0146
#
# Epoch 00057: val_mae did not improve from 1.95075
# Epoch 58/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.8323 - mse: 6.8323 - mae: 2.1236 - val_loss: 5.9835 - val_mse: 5.9835 - val_mae: 2.0148
#
# Epoch 00058: val_mae did not improve from 1.95075
# Epoch 59/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5458 - mse: 6.5458 - mae: 2.0325 - val_loss: 6.0007 - val_mse: 6.0007 - val_mae: 2.0201
#
# Epoch 00059: val_mae did not improve from 1.95075
# Epoch 60/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9524 - mse: 6.9524 - mae: 2.1461 - val_loss: 5.9946 - val_mse: 5.9946 - val_mae: 2.0181
#
# Epoch 00060: val_mae did not improve from 1.95075
# Epoch 61/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.1898 - mse: 7.1898 - mae: 2.0876 - val_loss: 5.9896 - val_mse: 5.9896 - val_mae: 2.0166
#
# Epoch 00061: val_mae did not improve from 1.95075
# Epoch 62/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.0197 - mse: 6.0197 - mae: 1.9665 - val_loss: 5.9649 - val_mse: 5.9649 - val_mae: 2.0093
#
# Epoch 00062: val_mae did not improve from 1.95075
# Epoch 63/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9226 - mse: 6.9226 - mae: 2.0955 - val_loss: 5.9599 - val_mse: 5.9599 - val_mae: 2.0077
#
# Epoch 00063: val_mae did not improve from 1.95075
# Epoch 64/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2784 - mse: 6.2784 - mae: 1.9618 - val_loss: 5.9817 - val_mse: 5.9817 - val_mae: 2.0143
#
# Epoch 00064: val_mae did not improve from 1.95075
# Epoch 65/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4951 - mse: 6.4951 - mae: 2.0135 - val_loss: 5.9663 - val_mse: 5.9663 - val_mae: 2.0097
#
# Epoch 00065: val_mae did not improve from 1.95075
# Epoch 66/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.0012 - mse: 7.0012 - mae: 2.0974 - val_loss: 5.9672 - val_mse: 5.9672 - val_mae: 2.0100
#
# Epoch 00066: val_mae did not improve from 1.95075
# Epoch 67/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.3647 - mse: 6.3647 - mae: 1.9824 - val_loss: 5.9563 - val_mse: 5.9563 - val_mae: 2.0065
#
# Epoch 00067: val_mae did not improve from 1.95075
# Epoch 68/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.8904 - mse: 5.8904 - mae: 1.9411 - val_loss: 5.9659 - val_mse: 5.9659 - val_mae: 2.0096
#
# Epoch 00068: val_mae did not improve from 1.95075
# Epoch 69/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5320 - mse: 6.5320 - mae: 2.0678 - val_loss: 5.9579 - val_mse: 5.9579 - val_mae: 2.0071
#
# Epoch 00069: val_mae did not improve from 1.95075
# Epoch 70/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5066 - mse: 6.5066 - mae: 2.0146 - val_loss: 5.9874 - val_mse: 5.9874 - val_mae: 2.0160
#
# Epoch 00070: val_mae did not improve from 1.95075
# Epoch 71/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5099 - mse: 6.5099 - mae: 1.9846 - val_loss: 5.9707 - val_mse: 5.9707 - val_mae: 2.0111
#
# Epoch 00071: val_mae did not improve from 1.95075
# Epoch 72/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2956 - mse: 6.2956 - mae: 2.0211 - val_loss: 5.9697 - val_mse: 5.9697 - val_mae: 2.0108
#
# Epoch 00072: val_mae did not improve from 1.95075
# Epoch 73/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4350 - mse: 6.4350 - mae: 2.0149 - val_loss: 5.9936 - val_mse: 5.9936 - val_mae: 2.0178
#
# Epoch 00073: val_mae did not improve from 1.95075
# Epoch 74/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9877 - mse: 5.9877 - mae: 1.9701 - val_loss: 5.9637 - val_mse: 5.9637 - val_mae: 2.0089
#
# Epoch 00074: val_mae did not improve from 1.95075
# Epoch 75/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.8277 - mse: 6.8277 - mae: 2.0938 - val_loss: 5.9780 - val_mse: 5.9780 - val_mae: 2.0132
#
# Epoch 00075: val_mae did not improve from 1.95075
# Epoch 76/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.0427 - mse: 6.0427 - mae: 1.9196 - val_loss: 5.9948 - val_mse: 5.9948 - val_mae: 2.0182
#
# Epoch 00076: val_mae did not improve from 1.95075
# Epoch 77/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.1592 - mse: 7.1592 - mae: 2.1174 - val_loss: 5.9611 - val_mse: 5.9611 - val_mae: 2.0081
#
# Epoch 00077: val_mae did not improve from 1.95075
# Epoch 78/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.8788 - mse: 5.8788 - mae: 1.9201 - val_loss: 5.9638 - val_mse: 5.9638 - val_mae: 2.0090
#
# Epoch 00078: val_mae did not improve from 1.95075
# Epoch 79/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.4065 - mse: 6.4065 - mae: 1.9737 - val_loss: 5.9731 - val_mse: 5.9731 - val_mae: 2.0118
#
# Epoch 00079: val_mae did not improve from 1.95075
# Epoch 80/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.3664 - mse: 6.3664 - mae: 1.9717 - val_loss: 5.9852 - val_mse: 5.9852 - val_mae: 2.0153
#
# Epoch 00080: val_mae did not improve from 1.95075
# Epoch 81/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9544 - mse: 6.9544 - mae: 2.0458 - val_loss: 5.9758 - val_mse: 5.9758 - val_mae: 2.0126
#
# Epoch 00081: val_mae did not improve from 1.95075
# Epoch 82/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.8271 - mse: 6.8271 - mae: 2.0914 - val_loss: 5.9707 - val_mse: 5.9707 - val_mae: 2.0111
#
# Epoch 00082: val_mae did not improve from 1.95075
# Epoch 83/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.3593 - mse: 6.3593 - mae: 2.0029 - val_loss: 5.9563 - val_mse: 5.9563 - val_mae: 2.0066
#
# Epoch 00083: val_mae did not improve from 1.95075
# Epoch 84/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.0703 - mse: 7.0703 - mae: 2.1419 - val_loss: 5.9712 - val_mse: 5.9712 - val_mae: 2.0113
#
# Epoch 00084: val_mae did not improve from 1.95075
# Epoch 85/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9748 - mse: 6.9748 - mae: 2.0207 - val_loss: 5.9816 - val_mse: 5.9816 - val_mae: 2.0143
#
# Epoch 00085: val_mae did not improve from 1.95075
# Epoch 86/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9889 - mse: 5.9889 - mae: 1.9775 - val_loss: 5.9640 - val_mse: 5.9640 - val_mae: 2.0091
#
# Epoch 00086: val_mae did not improve from 1.95075
# Epoch 87/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.3744 - mse: 7.3744 - mae: 2.1046 - val_loss: 5.9679 - val_mse: 5.9679 - val_mae: 2.0103
#
# Epoch 00087: val_mae did not improve from 1.95075
# Epoch 88/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.8100 - mse: 5.8100 - mae: 1.9612 - val_loss: 5.9528 - val_mse: 5.9528 - val_mae: 2.0054
#
# Epoch 00088: val_mae did not improve from 1.95075
# Epoch 89/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.1758 - mse: 7.1758 - mae: 2.1653 - val_loss: 5.9920 - val_mse: 5.9920 - val_mae: 2.0173
#
# Epoch 00089: val_mae did not improve from 1.95075
# Epoch 90/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.8480 - mse: 6.8480 - mae: 2.0586 - val_loss: 6.0209 - val_mse: 6.0209 - val_mae: 2.0266
#
# Epoch 00090: val_mae did not improve from 1.95075
# Epoch 91/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 6.6108 - mse: 6.6108 - mae: 2.0545 - val_loss: 6.0055 - val_mse: 6.0055 - val_mae: 2.0217
#
# Epoch 00091: val_mae did not improve from 1.95075
# Epoch 92/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 7.4987 - mse: 7.4987 - mae: 2.1632 - val_loss: 5.9794 - val_mse: 5.9794 - val_mae: 2.0137
#
# Epoch 00092: val_mae did not improve from 1.95075
# Epoch 93/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.6387 - mse: 6.6387 - mae: 1.9988 - val_loss: 5.9727 - val_mse: 5.9727 - val_mae: 2.0117
#
# Epoch 00093: val_mae did not improve from 1.95075
# Epoch 94/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.2598 - mse: 7.2598 - mae: 2.1322 - val_loss: 5.9817 - val_mse: 5.9817 - val_mae: 2.0144
#
# Epoch 00094: val_mae did not improve from 1.95075
# Epoch 95/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.6135 - mse: 5.6135 - mae: 1.8980 - val_loss: 5.9691 - val_mse: 5.9691 - val_mae: 2.0107
#
# Epoch 00095: val_mae did not improve from 1.95075
# Epoch 96/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.7868 - mse: 6.7868 - mae: 2.0953 - val_loss: 5.9883 - val_mse: 5.9883 - val_mae: 2.0163
#
# Epoch 00096: val_mae did not improve from 1.95075
# Epoch 97/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9034 - mse: 5.9034 - mae: 1.9874 - val_loss: 5.9748 - val_mse: 5.9748 - val_mae: 2.0123
#
# Epoch 00097: val_mae did not improve from 1.95075
# Epoch 98/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2200 - mse: 6.2200 - mae: 1.9493 - val_loss: 5.9886 - val_mse: 5.9886 - val_mae: 2.0164
#
# Epoch 00098: val_mae did not improve from 1.95075
# Epoch 99/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2563 - mse: 6.2563 - mae: 2.0170 - val_loss: 5.9851 - val_mse: 5.9851 - val_mae: 2.0154
#
# Epoch 00099: val_mae did not improve from 1.95075
# Epoch 100/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5422 - mse: 6.5422 - mae: 2.0632 - val_loss: 5.9628 - val_mse: 5.9628 - val_mae: 2.0087
#
# Epoch 00100: val_mae did not improve from 1.95075
# Epoch 101/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.2508 - mse: 7.2508 - mae: 2.1319 - val_loss: 5.9909 - val_mse: 5.9909 - val_mae: 2.0170
#
# Epoch 00101: val_mae did not improve from 1.95075
# Epoch 102/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.3281 - mse: 6.3281 - mae: 2.0093 - val_loss: 5.9641 - val_mse: 5.9641 - val_mae: 2.0092
#
# Epoch 00102: val_mae did not improve from 1.95075
# Epoch 103/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.2427 - mse: 6.2427 - mae: 1.9944 - val_loss: 5.9715 - val_mse: 5.9715 - val_mae: 2.0114
#
# Epoch 00103: val_mae did not improve from 1.95075
# Epoch 104/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5073 - mse: 6.5073 - mae: 2.0333 - val_loss: 5.9650 - val_mse: 5.9650 - val_mae: 2.0094
#
# Epoch 00104: val_mae did not improve from 1.95075
# Epoch 105/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5609 - mse: 6.5609 - mae: 2.0672 - val_loss: 5.9806 - val_mse: 5.9806 - val_mae: 2.0141
#
# Epoch 00105: val_mae did not improve from 1.95075
# Epoch 106/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.0687 - mse: 7.0687 - mae: 2.0962 - val_loss: 5.9843 - val_mse: 5.9843 - val_mae: 2.0152
#
# Epoch 00106: val_mae did not improve from 1.95075
# Epoch 107/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.4346 - mse: 7.4346 - mae: 2.1222 - val_loss: 5.9713 - val_mse: 5.9713 - val_mae: 2.0114
#
# Epoch 00107: val_mae did not improve from 1.95075
# Epoch 108/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.5531 - mse: 6.5531 - mae: 2.0346 - val_loss: 5.9685 - val_mse: 5.9685 - val_mae: 2.0105
#
# Epoch 00108: val_mae did not improve from 1.95075
# Epoch 109/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9394 - mse: 5.9394 - mae: 1.9534 - val_loss: 5.9560 - val_mse: 5.9560 - val_mae: 2.0066
#
# Epoch 00109: val_mae did not improve from 1.95075
# Epoch 110/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9428 - mse: 6.9428 - mae: 2.0643 - val_loss: 6.0141 - val_mse: 6.0141 - val_mae: 2.0244
#
# Epoch 00110: val_mae did not improve from 1.95075
# Epoch 111/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 5.9227 - mse: 5.9227 - mae: 1.9709 - val_loss: 5.9811 - val_mse: 5.9811 - val_mae: 2.0142
#
# Epoch 00111: val_mae did not improve from 1.95075
# Epoch 112/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.9647 - mse: 6.9647 - mae: 2.0420 - val_loss: 5.9809 - val_mse: 5.9809 - val_mae: 2.0142
#
# Epoch 00112: val_mae did not improve from 1.95075
# Epoch 113/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 6.1733 - mse: 6.1733 - mae: 1.9720 - val_loss: 5.9505 - val_mse: 5.9505 - val_mae: 2.0047
#
# Epoch 00113: val_mae did not improve from 1.95075
# Epoch 114/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 7.0755 - mse: 7.0755 - mae: 2.0408 - val_loss: 5.9795 - val_mse: 5.9795 - val_mae: 2.0138
#
# Epoch 00114: val_mae did not improve from 1.95075
# Epoch 00114: early stopping

# %%
def show_info(model, X, y, log, weights = None):
    '''
    Show metrics about the evaluation model and plots about loss, rmse and rmspe
    '''
    if (log != None):
        # summarize history for loss
        plt.figure(figsize=(14,10))
        plt.plot(log.history['loss'])
        plt.plot(log.history['val_loss'])
        plt.title('Model Loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MAE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mae'])
        plt.plot(log.history['val_mae'])
        plt.title('Model MAE')
        plt.ylabel('MAE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MSE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mse'])
        plt.plot(log.history['val_mse'])
        plt.title('Model MSE')
        plt.ylabel('MSE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')
    if (weights != None):
        model.load_weights(weights)

    predictions = model.predict(X, verbose=1)

    mse = mean_squared_error(y, predictions)
    mae= mean_absolute_error(y, predictions)

# %%
show_info(model, x_test, y_test, log, weights='/home/m-marouni/Documents/CE-901/Heathrow/best_weights')
# Out:
# 11/11 [==============================] - 0s 795us/step
