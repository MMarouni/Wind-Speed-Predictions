# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import seed

seed(1)
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor 

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
df=pd.read_excel('Pre-Processed-Data.xlsx')
df.head()
# Out:
#    Wind Speed  Pressure  Pressure Grad  Wind Gradient
# 0        2.47    1029.0             -8              3
# 1        7.42    1021.4              0              8
# 2        6.81    1021.8             11              7
# 3        3.94    1033.7             -1              2
# 4        3.33    1033.4            -11              5

# %%
df.isnull().sum()
# Out:
# Wind Speed       0
# Pressure         0
# Pressure Grad    0
# Wind Gradient    0
# dtype: int64

# %%
X = df.drop(['Wind Speed'], axis=1)
#Assign the Target column as the output 
Y= df['Wind Speed']

# %%
X_norm=(X-X.min())/(X.max()-X.min())
X_norm
# Out:
#       Pressure  Pressure Grad  Wind Gradient
# 0     0.752055       0.449275       0.200000
# 1     0.647945       0.565217       0.533333
# 2     0.653425       0.724638       0.466667
# 3     0.816438       0.550725       0.133333
# 4     0.812329       0.405797       0.333333
# ...        ...            ...            ...
# 1091  0.706849       0.623188       0.066667
# 1092  0.767123       0.594203       0.200000
# 1093  0.795890       0.594203       0.266667
# 1094  0.831507       0.565217       0.200000
# 1095  0.836986       0.594203       0.200000
#
# [1096 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X_norm, Y, test_size=0.3, random_state=0)

# %%
model = Sequential()
model.add(Dense(8, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2)) #dropping a few neurons for generalizing the model
model.add(Dense(16, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2))   
model.add(Dense(1, activation="linear", kernel_initializer='normal'))
adam = Adam(learning_rate=1e-3, decay=1e-3)

# Compile model
model.compile(loss="mean_squared_error", optimizer='adam', metrics=['mse','mae'])

# %%
print('Fit model...')
filepath="/home/m-marouni/Documents/CE-901/Heathrow/best_weights"
checkpoint = ModelCheckpoint(filepath, monitor='val_mae', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_mae', patience=100, verbose=1, mode='min')
callbacks_list = [checkpoint, early_stopping]

log = model.fit(x_train, y_train,
          validation_split=0.40, batch_size=30, epochs=1000, shuffle=True, callbacks=callbacks_list)
# Out:
# Fit model...
# Epoch 1/1000
# 16/16 [==============================] - 11s 36ms/step - loss: 42.0107 - mse: 42.0107 - mae: 5.9291 - val_loss: 34.5733 - val_mse: 34.5733 - val_mae: 5.3558
#
# Epoch 00001: val_mae improved from inf to 5.35576, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 2/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 38.8135 - mse: 38.8135 - mae: 5.6890 - val_loss: 30.4519 - val_mse: 30.4519 - val_mae: 4.9561
#
# Epoch 00002: val_mae improved from 5.35576 to 4.95609, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 3/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 34.4020 - mse: 34.4020 - mae: 5.3081 - val_loss: 26.1770 - val_mse: 26.1770 - val_mae: 4.5044
#
# Epoch 00003: val_mae improved from 4.95609 to 4.50444, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 4/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 26.7158 - mse: 26.7158 - mae: 4.5869 - val_loss: 21.9479 - val_mse: 21.9479 - val_mae: 4.0108
#
# Epoch 00004: val_mae improved from 4.50444 to 4.01082, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 5/1000
# 16/16 [==============================] - 0s 7ms/step - loss: 24.4494 - mse: 24.4494 - mae: 4.2742 - val_loss: 18.0524 - val_mse: 18.0524 - val_mae: 3.5007
#
# Epoch 00005: val_mae improved from 4.01082 to 3.50069, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 6/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 19.0380 - mse: 19.0380 - mae: 3.6197 - val_loss: 14.8551 - val_mse: 14.8551 - val_mae: 3.0398
#
# Epoch 00006: val_mae improved from 3.50069 to 3.03981, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 7/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 16.6922 - mse: 16.6922 - mae: 3.2838 - val_loss: 12.2931 - val_mse: 12.2931 - val_mae: 2.6709
#
# Epoch 00007: val_mae improved from 3.03981 to 2.67087, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 8/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 14.0063 - mse: 14.0063 - mae: 2.9278 - val_loss: 10.3546 - val_mse: 10.3546 - val_mae: 2.4074
#
# Epoch 00008: val_mae improved from 2.67087 to 2.40740, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 9/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 12.0610 - mse: 12.0610 - mae: 2.5697 - val_loss: 8.8948 - val_mse: 8.8948 - val_mae: 2.2239
#
# Epoch 00009: val_mae improved from 2.40740 to 2.22389, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 10/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 9.2483 - mse: 9.2483 - mae: 2.1386 - val_loss: 7.8732 - val_mse: 7.8732 - val_mae: 2.1060
#
# Epoch 00010: val_mae improved from 2.22389 to 2.10600, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 11/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 8.7550 - mse: 8.7550 - mae: 2.2018 - val_loss: 7.0941 - val_mse: 7.0941 - val_mae: 2.0249
#
# Epoch 00011: val_mae improved from 2.10600 to 2.02486, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 12/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 8.1515 - mse: 8.1515 - mae: 2.0892 - val_loss: 6.5665 - val_mse: 6.5665 - val_mae: 1.9736
#
# Epoch 00012: val_mae improved from 2.02486 to 1.97360, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 13/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.6979 - mse: 7.6979 - mae: 2.0001 - val_loss: 6.2404 - val_mse: 6.2404 - val_mae: 1.9539
#
# Epoch 00013: val_mae improved from 1.97360 to 1.95393, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 14/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3004 - mse: 6.3004 - mae: 1.9080 - val_loss: 6.0491 - val_mse: 6.0491 - val_mae: 1.9508
#
# Epoch 00014: val_mae improved from 1.95393 to 1.95077, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 15/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2791 - mse: 6.2791 - mae: 1.9229 - val_loss: 5.9487 - val_mse: 5.9487 - val_mae: 1.9534
#
# Epoch 00015: val_mae did not improve from 1.95077
# Epoch 16/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6433 - mse: 6.6433 - mae: 1.9800 - val_loss: 5.9008 - val_mse: 5.9008 - val_mae: 1.9623
#
# Epoch 00016: val_mae did not improve from 1.95077
# Epoch 17/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.5490 - mse: 7.5490 - mae: 2.0501 - val_loss: 5.8890 - val_mse: 5.8890 - val_mae: 1.9711
#
# Epoch 00017: val_mae did not improve from 1.95077
# Epoch 18/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6771 - mse: 5.6771 - mae: 1.8365 - val_loss: 5.8916 - val_mse: 5.8916 - val_mae: 1.9782
#
# Epoch 00018: val_mae did not improve from 1.95077
# Epoch 19/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.3760 - mse: 7.3760 - mae: 2.1407 - val_loss: 5.9028 - val_mse: 5.9028 - val_mae: 1.9859
#
# Epoch 00019: val_mae did not improve from 1.95077
# Epoch 20/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1996 - mse: 6.1996 - mae: 2.0176 - val_loss: 5.9116 - val_mse: 5.9116 - val_mae: 1.9900
#
# Epoch 00020: val_mae did not improve from 1.95077
# Epoch 21/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.3686 - mse: 7.3686 - mae: 2.1172 - val_loss: 5.9271 - val_mse: 5.9271 - val_mae: 1.9961
#
# Epoch 00021: val_mae did not improve from 1.95077
# Epoch 22/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9366 - mse: 5.9366 - mae: 1.9263 - val_loss: 5.9285 - val_mse: 5.9285 - val_mae: 1.9967
#
# Epoch 00022: val_mae did not improve from 1.95077
# Epoch 23/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8610 - mse: 6.8610 - mae: 2.0709 - val_loss: 5.9505 - val_mse: 5.9505 - val_mae: 2.0046
#
# Epoch 00023: val_mae did not improve from 1.95077
# Epoch 24/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3197 - mse: 6.3197 - mae: 2.0062 - val_loss: 5.9551 - val_mse: 5.9551 - val_mae: 2.0061
#
# Epoch 00024: val_mae did not improve from 1.95077
# Epoch 25/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3044 - mse: 6.3044 - mae: 2.0037 - val_loss: 5.9552 - val_mse: 5.9552 - val_mae: 2.0062
#
# Epoch 00025: val_mae did not improve from 1.95077
# Epoch 26/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 5.9691 - mse: 5.9691 - mae: 1.9541 - val_loss: 5.9649 - val_mse: 5.9649 - val_mae: 2.0093
#
# Epoch 00026: val_mae did not improve from 1.95077
# Epoch 27/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4552 - mse: 6.4552 - mae: 2.0158 - val_loss: 5.9777 - val_mse: 5.9777 - val_mae: 2.0132
#
# Epoch 00027: val_mae did not improve from 1.95077
# Epoch 28/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.3921 - mse: 7.3921 - mae: 2.1559 - val_loss: 5.9846 - val_mse: 5.9846 - val_mae: 2.0152
#
# Epoch 00028: val_mae did not improve from 1.95077
# Epoch 29/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9541 - mse: 5.9541 - mae: 1.9257 - val_loss: 5.9813 - val_mse: 5.9813 - val_mae: 2.0142
#
# Epoch 00029: val_mae did not improve from 1.95077
# Epoch 30/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3747 - mse: 6.3747 - mae: 2.0513 - val_loss: 5.9875 - val_mse: 5.9875 - val_mae: 2.0160
#
# Epoch 00030: val_mae did not improve from 1.95077
# Epoch 31/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9765 - mse: 6.9765 - mae: 2.0690 - val_loss: 5.9901 - val_mse: 5.9901 - val_mae: 2.0167
#
# Epoch 00031: val_mae did not improve from 1.95077
# Epoch 32/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.2521 - mse: 7.2521 - mae: 2.1123 - val_loss: 5.9664 - val_mse: 5.9664 - val_mae: 2.0098
#
# Epoch 00032: val_mae did not improve from 1.95077
# Epoch 33/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9786 - mse: 5.9786 - mae: 1.9768 - val_loss: 5.9629 - val_mse: 5.9629 - val_mae: 2.0087
#
# Epoch 00033: val_mae did not improve from 1.95077
# Epoch 34/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4473 - mse: 6.4473 - mae: 2.0055 - val_loss: 5.9745 - val_mse: 5.9745 - val_mae: 2.0122
#
# Epoch 00034: val_mae did not improve from 1.95077
# Epoch 35/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0301 - mse: 7.0301 - mae: 2.1010 - val_loss: 5.9785 - val_mse: 5.9785 - val_mae: 2.0134
#
# Epoch 00035: val_mae did not improve from 1.95077
# Epoch 36/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 5.2879 - mse: 5.2879 - mae: 1.8513 - val_loss: 5.9806 - val_mse: 5.9806 - val_mae: 2.0140
#
# Epoch 00036: val_mae did not improve from 1.95077
# Epoch 37/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4207 - mse: 6.4207 - mae: 1.9868 - val_loss: 5.9874 - val_mse: 5.9874 - val_mae: 2.0160
#
# Epoch 00037: val_mae did not improve from 1.95077
# Epoch 38/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6423 - mse: 6.6423 - mae: 2.0680 - val_loss: 5.9802 - val_mse: 5.9802 - val_mae: 2.0139
#
# Epoch 00038: val_mae did not improve from 1.95077
# Epoch 39/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6180 - mse: 6.6180 - mae: 2.0653 - val_loss: 5.9846 - val_mse: 5.9846 - val_mae: 2.0152
#
# Epoch 00039: val_mae did not improve from 1.95077
# Epoch 40/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9736 - mse: 5.9736 - mae: 1.9200 - val_loss: 5.9795 - val_mse: 5.9795 - val_mae: 2.0137
#
# Epoch 00040: val_mae did not improve from 1.95077
# Epoch 41/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7818 - mse: 6.7818 - mae: 2.0745 - val_loss: 5.9780 - val_mse: 5.9780 - val_mae: 2.0133
#
# Epoch 00041: val_mae did not improve from 1.95077
# Epoch 42/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1168 - mse: 6.1168 - mae: 2.0119 - val_loss: 5.9578 - val_mse: 5.9578 - val_mae: 2.0071
#
# Epoch 00042: val_mae did not improve from 1.95077
# Epoch 43/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4204 - mse: 6.4204 - mae: 2.0023 - val_loss: 5.9834 - val_mse: 5.9834 - val_mae: 2.0148
#
# Epoch 00043: val_mae did not improve from 1.95077
# Epoch 44/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9666 - mse: 6.9666 - mae: 2.0919 - val_loss: 6.0073 - val_mse: 6.0073 - val_mae: 2.0222
#
# Epoch 00044: val_mae did not improve from 1.95077
# Epoch 45/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4540 - mse: 6.4540 - mae: 2.0099 - val_loss: 5.9991 - val_mse: 5.9991 - val_mae: 2.0197
#
# Epoch 00045: val_mae did not improve from 1.95077
# Epoch 46/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0098 - mse: 7.0098 - mae: 2.1262 - val_loss: 5.9808 - val_mse: 5.9808 - val_mae: 2.0141
#
# Epoch 00046: val_mae did not improve from 1.95077
# Epoch 47/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4959 - mse: 6.4959 - mae: 2.0145 - val_loss: 5.9558 - val_mse: 5.9558 - val_mae: 2.0064
#
# Epoch 00047: val_mae did not improve from 1.95077
# Epoch 48/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6297 - mse: 6.6297 - mae: 2.0323 - val_loss: 5.9612 - val_mse: 5.9612 - val_mae: 2.0082
#
# Epoch 00048: val_mae did not improve from 1.95077
# Epoch 49/1000
# 16/16 [==============================] - 0s 7ms/step - loss: 6.7241 - mse: 6.7241 - mae: 2.0756 - val_loss: 5.9629 - val_mse: 5.9629 - val_mae: 2.0088
#
# Epoch 00049: val_mae did not improve from 1.95077
# Epoch 50/1000
# 16/16 [==============================] - 0s 7ms/step - loss: 6.6513 - mse: 6.6513 - mae: 2.0498 - val_loss: 5.9747 - val_mse: 5.9747 - val_mae: 2.0123
#
# Epoch 00050: val_mae did not improve from 1.95077
# Epoch 51/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6353 - mse: 6.6353 - mae: 2.0464 - val_loss: 5.9651 - val_mse: 5.9651 - val_mae: 2.0094
#
# Epoch 00051: val_mae did not improve from 1.95077
# Epoch 52/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 7.6017 - mse: 7.6017 - mae: 2.1811 - val_loss: 5.9613 - val_mse: 5.9613 - val_mae: 2.0083
#
# Epoch 00052: val_mae did not improve from 1.95077
# Epoch 53/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 5.8564 - mse: 5.8564 - mae: 1.9283 - val_loss: 5.9645 - val_mse: 5.9645 - val_mae: 2.0093
#
# Epoch 00053: val_mae did not improve from 1.95077
# Epoch 54/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6340 - mse: 6.6340 - mae: 2.0086 - val_loss: 5.9753 - val_mse: 5.9753 - val_mae: 2.0125
#
# Epoch 00054: val_mae did not improve from 1.95077
# Epoch 55/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4353 - mse: 6.4353 - mae: 1.9804 - val_loss: 5.9638 - val_mse: 5.9638 - val_mae: 2.0090
#
# Epoch 00055: val_mae did not improve from 1.95077
# Epoch 56/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4549 - mse: 7.4549 - mae: 2.1276 - val_loss: 5.9768 - val_mse: 5.9768 - val_mae: 2.0130
#
# Epoch 00056: val_mae did not improve from 1.95077
# Epoch 57/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.1769 - mse: 6.1769 - mae: 2.0166 - val_loss: 5.9824 - val_mse: 5.9824 - val_mae: 2.0146
#
# Epoch 00057: val_mae did not improve from 1.95077
# Epoch 58/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8315 - mse: 6.8315 - mae: 2.1234 - val_loss: 5.9830 - val_mse: 5.9830 - val_mae: 2.0148
#
# Epoch 00058: val_mae did not improve from 1.95077
# Epoch 59/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5454 - mse: 6.5454 - mae: 2.0325 - val_loss: 6.0001 - val_mse: 6.0001 - val_mae: 2.0200
#
# Epoch 00059: val_mae did not improve from 1.95077
# Epoch 60/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9519 - mse: 6.9519 - mae: 2.1461 - val_loss: 5.9941 - val_mse: 5.9941 - val_mae: 2.0181
#
# Epoch 00060: val_mae did not improve from 1.95077
# Epoch 61/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.1896 - mse: 7.1896 - mae: 2.0875 - val_loss: 5.9890 - val_mse: 5.9890 - val_mae: 2.0165
#
# Epoch 00061: val_mae did not improve from 1.95077
# Epoch 62/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0194 - mse: 6.0194 - mae: 1.9665 - val_loss: 5.9643 - val_mse: 5.9643 - val_mae: 2.0092
#
# Epoch 00062: val_mae did not improve from 1.95077
# Epoch 63/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9219 - mse: 6.9219 - mae: 2.0954 - val_loss: 5.9592 - val_mse: 5.9592 - val_mae: 2.0076
#
# Epoch 00063: val_mae did not improve from 1.95077
# Epoch 64/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2780 - mse: 6.2780 - mae: 1.9617 - val_loss: 5.9811 - val_mse: 5.9811 - val_mae: 2.0142
#
# Epoch 00064: val_mae did not improve from 1.95077
# Epoch 65/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4949 - mse: 6.4949 - mae: 2.0135 - val_loss: 5.9656 - val_mse: 5.9656 - val_mae: 2.0096
#
# Epoch 00065: val_mae did not improve from 1.95077
# Epoch 66/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0005 - mse: 7.0005 - mae: 2.0972 - val_loss: 5.9665 - val_mse: 5.9665 - val_mae: 2.0099
#
# Epoch 00066: val_mae did not improve from 1.95077
# Epoch 67/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3644 - mse: 6.3644 - mae: 1.9823 - val_loss: 5.9557 - val_mse: 5.9557 - val_mae: 2.0065
#
# Epoch 00067: val_mae did not improve from 1.95077
# Epoch 68/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.8900 - mse: 5.8900 - mae: 1.9410 - val_loss: 5.9653 - val_mse: 5.9653 - val_mae: 2.0095
#
# Epoch 00068: val_mae did not improve from 1.95077
# Epoch 69/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5315 - mse: 6.5315 - mae: 2.0678 - val_loss: 5.9573 - val_mse: 5.9573 - val_mae: 2.0070
#
# Epoch 00069: val_mae did not improve from 1.95077
# Epoch 70/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5056 - mse: 6.5056 - mae: 2.0144 - val_loss: 5.9868 - val_mse: 5.9868 - val_mae: 2.0159
#
# Epoch 00070: val_mae did not improve from 1.95077
# Epoch 71/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5093 - mse: 6.5093 - mae: 1.9844 - val_loss: 5.9700 - val_mse: 5.9700 - val_mae: 2.0110
#
# Epoch 00071: val_mae did not improve from 1.95077
# Epoch 72/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2945 - mse: 6.2945 - mae: 2.0210 - val_loss: 5.9690 - val_mse: 5.9690 - val_mae: 2.0107
#
# Epoch 00072: val_mae did not improve from 1.95077
# Epoch 73/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4343 - mse: 6.4343 - mae: 2.0147 - val_loss: 5.9930 - val_mse: 5.9930 - val_mae: 2.0178
#
# Epoch 00073: val_mae did not improve from 1.95077
# Epoch 74/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9877 - mse: 5.9877 - mae: 1.9702 - val_loss: 5.9630 - val_mse: 5.9630 - val_mae: 2.0088
#
# Epoch 00074: val_mae did not improve from 1.95077
# Epoch 75/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 6.8276 - mse: 6.8276 - mae: 2.0937 - val_loss: 5.9773 - val_mse: 5.9773 - val_mae: 2.0132
#
# Epoch 00075: val_mae did not improve from 1.95077
# Epoch 76/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.0421 - mse: 6.0421 - mae: 1.9196 - val_loss: 5.9941 - val_mse: 5.9941 - val_mae: 2.0181
#
# Epoch 00076: val_mae did not improve from 1.95077
# Epoch 77/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.1584 - mse: 7.1584 - mae: 2.1173 - val_loss: 5.9603 - val_mse: 5.9603 - val_mae: 2.0080
#
# Epoch 00077: val_mae did not improve from 1.95077
# Epoch 78/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.8778 - mse: 5.8778 - mae: 1.9198 - val_loss: 5.9630 - val_mse: 5.9630 - val_mae: 2.0089
#
# Epoch 00078: val_mae did not improve from 1.95077
# Epoch 79/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.4059 - mse: 6.4059 - mae: 1.9736 - val_loss: 5.9724 - val_mse: 5.9724 - val_mae: 2.0117
#
# Epoch 00079: val_mae did not improve from 1.95077
# Epoch 80/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3658 - mse: 6.3658 - mae: 1.9716 - val_loss: 5.9845 - val_mse: 5.9845 - val_mae: 2.0153
#
# Epoch 00080: val_mae did not improve from 1.95077
# Epoch 81/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9543 - mse: 6.9543 - mae: 2.0458 - val_loss: 5.9751 - val_mse: 5.9751 - val_mae: 2.0125
#
# Epoch 00081: val_mae did not improve from 1.95077
# Epoch 82/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8264 - mse: 6.8264 - mae: 2.0913 - val_loss: 5.9699 - val_mse: 5.9699 - val_mae: 2.0110
#
# Epoch 00082: val_mae did not improve from 1.95077
# Epoch 83/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3592 - mse: 6.3592 - mae: 2.0029 - val_loss: 5.9555 - val_mse: 5.9555 - val_mae: 2.0065
#
# Epoch 00083: val_mae did not improve from 1.95077
# Epoch 84/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0697 - mse: 7.0697 - mae: 2.1419 - val_loss: 5.9704 - val_mse: 5.9704 - val_mae: 2.0112
#
# Epoch 00084: val_mae did not improve from 1.95077
# Epoch 85/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9745 - mse: 6.9745 - mae: 2.0206 - val_loss: 5.9808 - val_mse: 5.9808 - val_mae: 2.0142
#
# Epoch 00085: val_mae did not improve from 1.95077
# Epoch 86/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9881 - mse: 5.9881 - mae: 1.9774 - val_loss: 5.9632 - val_mse: 5.9632 - val_mae: 2.0090
#
# Epoch 00086: val_mae did not improve from 1.95077
# Epoch 87/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.3735 - mse: 7.3735 - mae: 2.1045 - val_loss: 5.9671 - val_mse: 5.9671 - val_mae: 2.0102
#
# Epoch 00087: val_mae did not improve from 1.95077
# Epoch 88/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.8093 - mse: 5.8093 - mae: 1.9611 - val_loss: 5.9519 - val_mse: 5.9519 - val_mae: 2.0053
#
# Epoch 00088: val_mae did not improve from 1.95077
# Epoch 89/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.1741 - mse: 7.1741 - mae: 2.1650 - val_loss: 5.9911 - val_mse: 5.9911 - val_mae: 2.0172
#
# Epoch 00089: val_mae did not improve from 1.95077
# Epoch 90/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8467 - mse: 6.8467 - mae: 2.0584 - val_loss: 6.0201 - val_mse: 6.0201 - val_mae: 2.0265
#
# Epoch 00090: val_mae did not improve from 1.95077
# Epoch 91/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6093 - mse: 6.6093 - mae: 2.0543 - val_loss: 6.0046 - val_mse: 6.0046 - val_mae: 2.0215
#
# Epoch 00091: val_mae did not improve from 1.95077
# Epoch 92/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.4981 - mse: 7.4981 - mae: 2.1631 - val_loss: 5.9784 - val_mse: 5.9784 - val_mae: 2.0135
#
# Epoch 00092: val_mae did not improve from 1.95077
# Epoch 93/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6379 - mse: 6.6379 - mae: 1.9987 - val_loss: 5.9717 - val_mse: 5.9717 - val_mae: 2.0116
#
# Epoch 00093: val_mae did not improve from 1.95077
# Epoch 94/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.2599 - mse: 7.2599 - mae: 2.1322 - val_loss: 5.9807 - val_mse: 5.9807 - val_mae: 2.0142
#
# Epoch 00094: val_mae did not improve from 1.95077
# Epoch 95/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.6125 - mse: 5.6125 - mae: 1.8978 - val_loss: 5.9682 - val_mse: 5.9682 - val_mae: 2.0106
#
# Epoch 00095: val_mae did not improve from 1.95077
# Epoch 96/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7855 - mse: 6.7855 - mae: 2.0952 - val_loss: 5.9874 - val_mse: 5.9874 - val_mae: 2.0162
#
# Epoch 00096: val_mae did not improve from 1.95077
# Epoch 97/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9029 - mse: 5.9029 - mae: 1.9874 - val_loss: 5.9738 - val_mse: 5.9738 - val_mae: 2.0122
#
# Epoch 00097: val_mae did not improve from 1.95077
# Epoch 98/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2190 - mse: 6.2190 - mae: 1.9491 - val_loss: 5.9877 - val_mse: 5.9877 - val_mae: 2.0163
#
# Epoch 00098: val_mae did not improve from 1.95077
# Epoch 99/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 6.2561 - mse: 6.2561 - mae: 2.0169 - val_loss: 5.9841 - val_mse: 5.9841 - val_mae: 2.0152
#
# Epoch 00099: val_mae did not improve from 1.95077
# Epoch 100/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5411 - mse: 6.5411 - mae: 2.0630 - val_loss: 5.9617 - val_mse: 5.9617 - val_mae: 2.0086
#
# Epoch 00100: val_mae did not improve from 1.95077
# Epoch 101/1000
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2505 - mse: 7.2505 - mae: 2.1317 - val_loss: 5.9898 - val_mse: 5.9898 - val_mae: 2.0169
#
# Epoch 00101: val_mae did not improve from 1.95077
# Epoch 102/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.3280 - mse: 6.3280 - mae: 2.0093 - val_loss: 5.9630 - val_mse: 5.9630 - val_mae: 2.0090
#
# Epoch 00102: val_mae did not improve from 1.95077
# Epoch 103/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.2422 - mse: 6.2422 - mae: 1.9943 - val_loss: 5.9705 - val_mse: 5.9705 - val_mae: 2.0113
#
# Epoch 00103: val_mae did not improve from 1.95077
# Epoch 104/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5066 - mse: 6.5066 - mae: 2.0332 - val_loss: 5.9640 - val_mse: 5.9640 - val_mae: 2.0093
#
# Epoch 00104: val_mae did not improve from 1.95077
# Epoch 105/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5603 - mse: 6.5603 - mae: 2.0672 - val_loss: 5.9796 - val_mse: 5.9796 - val_mae: 2.0140
#
# Epoch 00105: val_mae did not improve from 1.95077
# Epoch 106/1000
# 16/16 [==============================] - 0s 8ms/step - loss: 7.0678 - mse: 7.0678 - mae: 2.0962 - val_loss: 5.9833 - val_mse: 5.9833 - val_mae: 2.0151
#
# Epoch 00106: val_mae did not improve from 1.95077
# Epoch 107/1000
# 16/16 [==============================] - 0s 6ms/step - loss: 7.4349 - mse: 7.4349 - mae: 2.1222 - val_loss: 5.9703 - val_mse: 5.9703 - val_mae: 2.0112
#
# Epoch 00107: val_mae did not improve from 1.95077
# Epoch 108/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5530 - mse: 6.5530 - mae: 2.0347 - val_loss: 5.9674 - val_mse: 5.9674 - val_mae: 2.0104
#
# Epoch 00108: val_mae did not improve from 1.95077
# Epoch 109/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9386 - mse: 5.9386 - mae: 1.9533 - val_loss: 5.9549 - val_mse: 5.9549 - val_mae: 2.0064
#
# Epoch 00109: val_mae did not improve from 1.95077
# Epoch 110/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9425 - mse: 6.9425 - mae: 2.0641 - val_loss: 6.0132 - val_mse: 6.0132 - val_mae: 2.0244
#
# Epoch 00110: val_mae did not improve from 1.95077
# Epoch 111/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 5.9224 - mse: 5.9224 - mae: 1.9709 - val_loss: 5.9800 - val_mse: 5.9800 - val_mae: 2.0141
#
# Epoch 00111: val_mae did not improve from 1.95077
# Epoch 112/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.9640 - mse: 6.9640 - mae: 2.0419 - val_loss: 5.9798 - val_mse: 5.9798 - val_mae: 2.0141
#
# Epoch 00112: val_mae did not improve from 1.95077
# Epoch 113/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 6.1725 - mse: 6.1725 - mae: 1.9719 - val_loss: 5.9493 - val_mse: 5.9493 - val_mae: 2.0046
#
# Epoch 00113: val_mae did not improve from 1.95077
# Epoch 114/1000
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0742 - mse: 7.0742 - mae: 2.0406 - val_loss: 5.9785 - val_mse: 5.9785 - val_mae: 2.0137
#
# Epoch 00114: val_mae did not improve from 1.95077
# Epoch 00114: early stopping

# %%
def show_info(model, X, y, log, weights = None):
    '''
    Show metrics about the evaluation model and plots about loss, rmse and rmspe
    '''
    if (log != None):
        # summarize history for loss
        plt.figure(figsize=(14,10))
        plt.plot(log.history['loss'])
        plt.plot(log.history['val_loss'])
        plt.title('Model Loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MAE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mae'])
        plt.plot(log.history['val_mae'])
        plt.title('Model MAE')
        plt.ylabel('MAE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MSE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mse'])
        plt.plot(log.history['val_mse'])
        plt.title('Model MSE')
        plt.ylabel('MSE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')
    if (weights != None):
        model.load_weights(weights)

    predictions = model.predict(X, verbose=1)

    mse = mean_squared_error(y, predictions)
    mae= mean_absolute_error(y, predictions)

# %%
show_info(model, x_test, y_test, log, weights='/home/m-marouni/Documents/CE-901/Heathrow/best_weights')
# Out:
# 11/11 [==============================] - 0s 774us/step
