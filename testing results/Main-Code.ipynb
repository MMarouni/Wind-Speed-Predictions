# %% [markdown]
# # Submitted by: Mohamad Marouni
# # Data Description:
# ## Data provided is taken from 3 sources wundergound, metoblue, rkp5. Data consist of 6 features related to weather forecasting from 2018 to 2020
# # Main Task:
# ## Forecast the wind speed for different locations in the UK using neural network to ensure stable wind power generation

# %% [markdown]
# # 1. Loading Libraries

# %%
#Pre-Processing Libraries
import math
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import pandas as pd
from numpy.random import seed
import statsmodels.api as sm
import statsmodels.formula.api as smf

#Tensorflow & Keras libraries
seed(1)
import tensorflow
tensorflow.random.set_seed(1)
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor 
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping

#Scikit-Learn Librariers
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2.Data Pre-Processing

# %% [markdown]
# ## 2.1. Loading Data

# %%
df=pd.read_excel('data.xlsx')
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad
# 0             128             -8
# 1             188              0
# 2             265             11
# 3             248             -1
# 4             224            -11

# %% [markdown]
# ## 2.1.1. Data at first sight

# %%
df.head()
df.tail()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad
# 0             128             -8
# 1             188              0
# 2             265             11
# 3             248             -1
# 4             224            -11
#             Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 1091  2018-12-27   2.9        2.6      98.0        1.42    1025.7
# 1092  2018-12-28   4.6        4.3      97.5        1.86    1030.1
# 1093  2018-12-29   8.9        7.9      93.8        4.11    1032.2
# 1094  2018-12-30   7.0        7.0      99.9        2.75    1034.8
# 1095  2018-12-31   8.4        7.5      93.6        2.42    1035.2
#
#       Wind Direction  Pressure Grad
# 1091             235              4
# 1092             261              2
# 1093             255              2
# 1094             260              0
# 1095             280              2

# %% [markdown]
# ## 2.1.2. Number of rows and columns in the dataframe

# %%
df.shape
# Out:
# (1096, 8)

# %% [markdown]
# ## The data consist of 9 columns and 1096 rows

# %% [markdown]
# ## 2.2. Data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096 entries, 0 to 1095
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            1096 non-null   object
#  1   Temp            1096 non-null   float64
#  2   Dew Point       1092 non-null   float64
#  3   Humidity        1091 non-null   float64
#  4   Wind Speed      1087 non-null   float64
#  5   Pressure        1096 non-null   float64
#  6   Wind Direction  1096 non-null   int64
#  7   Pressure Grad   1096 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 68.6+ KB

# %% [markdown]
# ## Data is formed from float numbers, integers, and objects

# %% [markdown]
# ## 2.3. Statistical describtion for the numerical values

# %%
df.describe()
# Out:
#               Temp    Dew Point     Humidity   Wind Speed     Pressure  \
# count  1096.000000  1092.000000  1091.000000  1087.000000  1096.000000
# mean     11.742245     9.011172    84.016627     5.930791  1014.446624
# std       4.933582     4.763136     8.827645     2.491654    10.581680
# min      -2.600000    -9.200000    26.400000     1.220000   974.100000
# 25%       8.075000     5.600000    79.200000     4.030000  1008.175000
# 50%      11.300000     9.000000    85.000000     5.500000  1015.400000
# 75%      15.700000    12.700000    90.150000     7.390000  1021.500000
# max      25.100000    19.500000   100.000000    17.690000  1047.100000
#
#        Wind Direction  Pressure Grad
# count     1096.000000    1096.000000
# mean       184.674270      -0.435219
# std         69.980824       6.635824
# min         18.000000     -39.000000
# 25%        138.000000      -4.000000
# 50%        197.500000      -1.000000
# 75%        235.250000       3.000000
# max        339.000000      30.000000

# %% [markdown]
# ## 2.4. Null Values check

# %%
df.isnull().sum()
# Out:
# Date              0
# Temp              0
# Dew Point         4
# Humidity          5
# Wind Speed        9
# Pressure          0
# Wind Direction    0
# Pressure Grad     0
# dtype: int64

# %% [markdown]
# ## Misiing values are found in columns(Dew Point, Humidity, and Wind Speed)

# %% [markdown]
# ## percentage of missing values per column

# %%
missing_data = pd.DataFrame({'total_missing': df.isnull().sum(), 'perc_missing': (df.isnull().sum()/1096)*100})
missing_data
# Out:
#                 total_missing  perc_missing
# Date                        0      0.000000
# Temp                        0      0.000000
# Dew Point                   4      0.364964
# Humidity                    5      0.456204
# Wind Speed                  9      0.821168
# Pressure                    0      0.000000
# Wind Direction              0      0.000000
# Pressure Grad               0      0.000000

# %% [markdown]
# ## 2.4.1. Substitue null values with the mean value

# %%
#Fill the missing values with mean calculated for each column
df.fillna(df.mean(), inplace=True)

# %%
#No NaN values in the data 
df.isnull().sum()
# Out:
# Date              0
# Temp              0
# Dew Point         0
# Humidity          0
# Wind Speed        0
# Pressure          0
# Wind Direction    0
# Pressure Grad     0
# dtype: int64

# %% [markdown]
# ## 2.5. Divide the Date column into 3 columns(Year, Month, Day)

# %%
df['Year']  = df['Date'].apply(lambda x: int(str(x)[:4]))
df['Month'] = df['Date'].apply(lambda x: int(str(x)[5:7]))
df['Day']=df['Date'].apply(lambda x: int(str(x)[8:10]))
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad  Year  Month  Day
# 0             128             -8  2020      1    1
# 1             188              0  2020      1    2
# 2             265             11  2020      1    3
# 3             248             -1  2020      1    4
# 4             224            -11  2020      1    5

# %% [markdown]
# ## 2.5.1. Divide the date column into 3 columns days, months, and years

# %%
del df['Date']
df.head()
# Out:
#    Temp  Dew Point  Humidity  Wind Speed  Pressure  Wind Direction  \
# 0   5.7        4.8      94.4        2.47    1029.0             128
# 1   9.3        8.2      92.5        7.42    1021.4             188
# 2   8.2        6.8      91.4        6.81    1021.8             265
# 3   5.6        3.6      87.2        3.94    1033.7             248
# 4   7.8        6.1      89.2        3.33    1033.4             224
#
#    Pressure Grad  Year  Month  Day
# 0             -8  2020      1    1
# 1              0  2020      1    2
# 2             11  2020      1    3
# 3             -1  2020      1    4
# 4            -11  2020      1    5

# %% [markdown]
# ## Final shape of the dataframe

# %%
df.shape
# Out:
# (1096, 10)

# %% [markdown]
# ## 11 Columns and 1096 rows

# %% [markdown]
# # 3. Data Visualization

# %% [markdown]
# ## 3.1. Loading Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import lineplot
from seaborn import countplot
from seaborn import distplot
from seaborn import boxplot
from seaborn import scatterplot
from matplotlib import pyplot
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## 3.2. Linplots for the mean of each feature over 12 months

# %%
# group by date and get average sales, and percent change
avg_ws   = df.groupby('Month')["Wind Speed"].mean()
avg_t   = df.groupby('Month')["Temp"].mean()
avg_h   = df.groupby('Month')["Humidity"].mean()
month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
fig, (ax1, ax2, ax3)=plt.subplots(3,1,sharex=True,figsize=(15,8))
fig.tight_layout()
ax1 = avg_ws.plot(legend=True,ax=ax1,marker='o',title="Wind Speed", color='red')
ax2 = avg_t.plot(legend=True,ax=ax2,marker='o',title="Temperature", color='Blue')
ax3 = avg_h.plot(legend=True,ax=ax3,marker='o',title="Humidity", color='green')
plt.show()

# %%
# group by date and get average sales, and percent change
avg_dp  = df.groupby('Month')["Dew Point"].mean()
avg_p   = df.groupby('Month')["Pressure"].mean()
avg_pg   = df.groupby('Month')["Pressure Grad"].mean()
month=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']
fig, (ax1, ax2, ax3)=plt.subplots(3,1,sharex=True,figsize=(15,8))
fig.tight_layout()
ax1 = avg_dp.plot(legend=True,ax=ax1,marker='o',title="Dew Point", color='red')
ax2 = avg_p.plot(legend=True,ax=ax2,marker='o',title="Pressure", color='Blue')
ax3 = avg_pg.plot(legend=True,ax=ax3,marker='o',title="Pressure Gradient", color='green')
plt.show()

# %% [markdown]
# ## 3.3. Boxplot for features numerical distrbution

# %%
fig, (ax1,ax2,ax3,ax4,ax5,ax6,ax7) = plt.subplots(1,7,figsize=(20,4))
sns.boxplot( df['Temp'],ax=ax1)
sns.boxplot( df['Dew Point'],ax=ax2)
sns.boxplot( df['Humidity'], ax=ax3)
sns.boxplot( df['Wind Speed'], ax=ax4)
sns.boxplot( df['Pressure'], ax=ax5)
sns.boxplot( df['Wind Direction'], ax=ax6)
sns.boxplot( df['Pressure Grad'],ax=ax7)
# Out:
# <AxesSubplot:xlabel='Temp'>
# <AxesSubplot:xlabel='Dew Point'>
# <AxesSubplot:xlabel='Humidity'>
# <AxesSubplot:xlabel='Wind Speed'>
# <AxesSubplot:xlabel='Pressure'>
# <AxesSubplot:xlabel='Wind Direction'>
# <AxesSubplot:xlabel='Pressure Grad'>

# %% [markdown]
# ## 3.4. Correlation of the features according to the correlation factor

# %%
plt.figure(figsize = (20,10))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':25}, pad=10);

# %% [markdown]
# ## According to the heatmap provided the main inputs that have high impact on wind speed are (Pressure, Wind Gradient, and Pressure gradient) to improve the generalization ability of the model and to prduce predictions with less error the other features will be deleted

# %%
del df['Temp']
del df['Humidity']
del df['Wind Direction']
del df['Year']
del df['Month']
del df['Day']

# %%
plt.figure(figsize = (20,10))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':25}, pad=10);

# %% [markdown]
# ## 3.5. Final shape of the dataset

# %%
df.head()
df.tail()
df.shape
# Out:
#    Dew Point  Wind Speed  Pressure  Pressure Grad
# 0        4.8        2.47    1029.0             -8
# 1        8.2        7.42    1021.4              0
# 2        6.8        6.81    1021.8             11
# 3        3.6        3.94    1033.7             -1
# 4        6.1        3.33    1033.4            -11
#       Dew Point  Wind Speed  Pressure  Pressure Grad
# 1091        2.6        1.42    1025.7              4
# 1092        4.3        1.86    1030.1              2
# 1093        7.9        4.11    1032.2              2
# 1094        7.0        2.75    1034.8              0
# 1095        7.5        2.42    1035.2              2
# (1096, 4)

# %% [markdown]
# # 4. Feature Engineering

# %% [markdown]
# ## 4.1. Create 2 variables X & Y. X represents the input features and Y represent the output feature

# %%
X = df.drop(['Wind Speed'], axis=1)
#Assign the Target column as the output 
Y= df['Wind Speed']

# %% [markdown]
# ## 4.2. Input features Normalization

# %%
X_norm=(X-X.min())/(X.max()-X.min())

# %% [markdown]
# ## All input features are between 0 and 1

# %%
X_norm
# Out:
#       Dew Point  Pressure  Pressure Grad
# 0      0.487805  0.752055       0.449275
# 1      0.606272  0.647945       0.565217
# 2      0.557491  0.653425       0.724638
# 3      0.445993  0.816438       0.550725
# 4      0.533101  0.812329       0.405797
# ...         ...       ...            ...
# 1091   0.411150  0.706849       0.623188
# 1092   0.470383  0.767123       0.594203
# 1093   0.595819  0.795890       0.594203
# 1094   0.564460  0.831507       0.565217
# 1095   0.581882  0.836986       0.594203
#
# [1096 rows x 3 columns]

# %% [markdown]
# ## 4.3. Data split 80% training and 20% testing

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X_norm, Y, test_size=0.2, random_state=0)

# %% [markdown]
# ## x_train shape

# %%
x_train.head()
x_train.tail()
# Out:
#       Dew Point  Pressure  Pressure Grad
# 384    0.362369  0.498630       0.652174
# 351    0.637631  0.563014       0.521739
# 1057   0.571429  0.532877       0.492754
# 622    0.752613  0.784932       0.449275
# 188    0.693380  0.630137       0.478261
#       Dew Point  Pressure  Pressure Grad
# 1033   0.505226  0.287671       0.724638
# 763    0.390244  0.479452       0.536232
# 835    0.644599  0.493151       0.623188
# 559    0.836237  0.638356       0.579710
# 684    0.494774  0.356164       0.637681

# %%
x_train.shape
# Out:
# (876, 3)

# %% [markdown]
# ## y_train shape

# %%
y_train.shape
# Out:
# (876,)

# %%
y_train.head()
y_train.tail()
# Out:
# 384     6.39
# 351     7.14
# 1057    3.94
# 622     3.81
# 188     4.97
# Name: Wind Speed, dtype: float64
# 1033    7.11
# 763     5.94
# 835     4.44
# 559     3.56
# 684     6.81
# Name: Wind Speed, dtype: float64

# %% [markdown]
# # 5.Model Setup

# %% [markdown]
# ## 5.1. Intialize the model
# ## Model is formed of input layer with 4 neurons, Hidden layer with 32 neurons, and output layer with one neuron
# ## 20% dropout function is used
# ## ADAM Optimizer
# ## Learning rate=1e-3
# ## Decay rate=1e-3

# %%
model = Sequential()
model.add(Dense(32, input_dim=x_train.shape[1], activation="sigmoid", kernel_initializer='normal'))
model.add(Dropout(0.2)) #dropping a few neurons for generalizing the model
model.add(Dense(1, activation="linear", kernel_initializer='normal'))
adam = Adam(learning_rate=1e-3, decay=1e-3)

# %% [markdown]
# ## 5.2. Compile model
# ## Evalution metrics: Mean absolute error(MAE) & Mean squared error(MSE)

# %%
# Compile model
model.compile(loss="mean_squared_error", optimizer='adam', metrics=['mse','mae'])

# %% [markdown]
# ## 5.3. Model fitting
# ## Best fit weights are save in the filepath
# ## Early stopping with patience=100 and moniotr=val_mae
# ## Epochs=1000
# ## Batch_size=30

# %%
print('Fit model...')
filepath="/home/m-marouni/Documents/CE-901/Heathrow/best_weights"
checkpoint = ModelCheckpoint(filepath, monitor='val_mae', verbose=1, save_best_only=True, mode='min')
early_stopping = EarlyStopping(monitor='val_mae', patience=100, verbose=1, mode='min')
callbacks_list = [checkpoint, early_stopping]

log = model.fit(x_train, y_train,
          validation_split=0.40, batch_size=30, epochs=1000, shuffle=True, callbacks=callbacks_list)
# Out:
# Fit model...
# Epoch 1/1000
# 18/18 [==============================] - 11s 27ms/step - loss: 43.3296 - mse: 43.3296 - mae: 6.0486 - val_loss: 36.3460 - val_mse: 36.3460 - val_mae: 5.5389
#
# Epoch 00001: val_mae improved from inf to 5.53891, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 2/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 39.0819 - mse: 39.0819 - mae: 5.6807 - val_loss: 32.9990 - val_mse: 32.9990 - val_mae: 5.2279
#
# Epoch 00002: val_mae improved from 5.53891 to 5.22789, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 3/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 36.6171 - mse: 36.6171 - mae: 5.4259 - val_loss: 29.7992 - val_mse: 29.7992 - val_mae: 4.9121
#
# Epoch 00003: val_mae improved from 5.22789 to 4.91208, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 4/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 32.5087 - mse: 32.5087 - mae: 5.0703 - val_loss: 26.7501 - val_mse: 26.7501 - val_mae: 4.5908
#
# Epoch 00004: val_mae improved from 4.91208 to 4.59081, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 5/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 29.6074 - mse: 29.6074 - mae: 4.7631 - val_loss: 23.7988 - val_mse: 23.7988 - val_mae: 4.2584
#
# Epoch 00005: val_mae improved from 4.59081 to 4.25839, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 6/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 27.6187 - mse: 27.6187 - mae: 4.4823 - val_loss: 21.0432 - val_mse: 21.0432 - val_mae: 3.9225
#
# Epoch 00006: val_mae improved from 4.25839 to 3.92255, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 7/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 22.6360 - mse: 22.6360 - mae: 4.0588 - val_loss: 18.4572 - val_mse: 18.4572 - val_mae: 3.5827
#
# Epoch 00007: val_mae improved from 3.92255 to 3.58267, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 8/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 20.2574 - mse: 20.2574 - mae: 3.6766 - val_loss: 16.0852 - val_mse: 16.0852 - val_mae: 3.2473
#
# Epoch 00008: val_mae improved from 3.58267 to 3.24731, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 9/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 18.6558 - mse: 18.6558 - mae: 3.4652 - val_loss: 13.9682 - val_mse: 13.9682 - val_mae: 2.9365
#
# Epoch 00009: val_mae improved from 3.24731 to 2.93645, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 10/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 16.0277 - mse: 16.0277 - mae: 3.0899 - val_loss: 12.1285 - val_mse: 12.1285 - val_mae: 2.6695
#
# Epoch 00010: val_mae improved from 2.93645 to 2.66952, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 11/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 13.3815 - mse: 13.3815 - mae: 2.7625 - val_loss: 10.5927 - val_mse: 10.5927 - val_mae: 2.4582
#
# Epoch 00011: val_mae improved from 2.66952 to 2.45820, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 12/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 11.1736 - mse: 11.1736 - mae: 2.4614 - val_loss: 9.3329 - val_mse: 9.3329 - val_mae: 2.2927
#
# Epoch 00012: val_mae improved from 2.45820 to 2.29274, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 13/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 11.0683 - mse: 11.0683 - mae: 2.4542 - val_loss: 8.3015 - val_mse: 8.3015 - val_mae: 2.1638
#
# Epoch 00013: val_mae improved from 2.29274 to 2.16376, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 14/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 10.7869 - mse: 10.7869 - mae: 2.3641 - val_loss: 7.5512 - val_mse: 7.5512 - val_mae: 2.0733
#
# Epoch 00014: val_mae improved from 2.16376 to 2.07328, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 15/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 9.4634 - mse: 9.4634 - mae: 2.1843 - val_loss: 6.9841 - val_mse: 6.9841 - val_mae: 2.0091
#
# Epoch 00015: val_mae improved from 2.07328 to 2.00912, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 16/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 8.0245 - mse: 8.0245 - mae: 2.1044 - val_loss: 6.5496 - val_mse: 6.5496 - val_mae: 1.9637
#
# Epoch 00016: val_mae improved from 2.00912 to 1.96365, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 17/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 8.5972 - mse: 8.5972 - mae: 2.1991 - val_loss: 6.2505 - val_mse: 6.2505 - val_mae: 1.9380
#
# Epoch 00017: val_mae improved from 1.96365 to 1.93804, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 18/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.2989 - mse: 7.2989 - mae: 1.9890 - val_loss: 6.0730 - val_mse: 6.0730 - val_mae: 1.9316
#
# Epoch 00018: val_mae improved from 1.93804 to 1.93155, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 19/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0414 - mse: 7.0414 - mae: 2.0514 - val_loss: 5.9451 - val_mse: 5.9451 - val_mae: 1.9307
#
# Epoch 00019: val_mae improved from 1.93155 to 1.93073, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 20/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9474 - mse: 6.9474 - mae: 1.9655 - val_loss: 5.8760 - val_mse: 5.8760 - val_mae: 1.9322
#
# Epoch 00020: val_mae did not improve from 1.93073
# Epoch 21/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7648 - mse: 6.7648 - mae: 2.0283 - val_loss: 5.8363 - val_mse: 5.8363 - val_mae: 1.9363
#
# Epoch 00021: val_mae did not improve from 1.93073
# Epoch 22/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0022 - mse: 7.0022 - mae: 2.0575 - val_loss: 5.8173 - val_mse: 5.8173 - val_mae: 1.9405
#
# Epoch 00022: val_mae did not improve from 1.93073
# Epoch 23/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 7.4001 - mse: 7.4001 - mae: 2.1089 - val_loss: 5.8108 - val_mse: 5.8108 - val_mae: 1.9450
#
# Epoch 00023: val_mae did not improve from 1.93073
# Epoch 24/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8536 - mse: 6.8536 - mae: 2.0458 - val_loss: 5.8095 - val_mse: 5.8095 - val_mae: 1.9478
#
# Epoch 00024: val_mae did not improve from 1.93073
# Epoch 25/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.8513 - mse: 7.8513 - mae: 2.1769 - val_loss: 5.8127 - val_mse: 5.8127 - val_mae: 1.9527
#
# Epoch 00025: val_mae did not improve from 1.93073
# Epoch 26/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.7023 - mse: 7.7023 - mae: 2.1959 - val_loss: 5.8150 - val_mse: 5.8150 - val_mae: 1.9550
#
# Epoch 00026: val_mae did not improve from 1.93073
# Epoch 27/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2178 - mse: 7.2178 - mae: 2.1175 - val_loss: 5.8166 - val_mse: 5.8166 - val_mae: 1.9565
#
# Epoch 00027: val_mae did not improve from 1.93073
# Epoch 28/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.1553 - mse: 6.1553 - mae: 1.9674 - val_loss: 5.8191 - val_mse: 5.8191 - val_mae: 1.9582
#
# Epoch 00028: val_mae did not improve from 1.93073
# Epoch 29/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8125 - mse: 6.8125 - mae: 2.0748 - val_loss: 5.8175 - val_mse: 5.8175 - val_mae: 1.9580
#
# Epoch 00029: val_mae did not improve from 1.93073
# Epoch 30/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 6.9195 - mse: 6.9195 - mae: 2.0820 - val_loss: 5.8268 - val_mse: 5.8268 - val_mae: 1.9628
#
# Epoch 00030: val_mae did not improve from 1.93073
# Epoch 31/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3927 - mse: 6.3927 - mae: 2.0325 - val_loss: 5.8284 - val_mse: 5.8284 - val_mae: 1.9641
#
# Epoch 00031: val_mae did not improve from 1.93073
# Epoch 32/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.2255 - mse: 6.2255 - mae: 1.9809 - val_loss: 5.8220 - val_mse: 5.8220 - val_mae: 1.9618
#
# Epoch 00032: val_mae did not improve from 1.93073
# Epoch 33/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4393 - mse: 6.4393 - mae: 2.0577 - val_loss: 5.8185 - val_mse: 5.8185 - val_mae: 1.9608
#
# Epoch 00033: val_mae did not improve from 1.93073
# Epoch 34/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.2814 - mse: 6.2814 - mae: 2.0415 - val_loss: 5.8184 - val_mse: 5.8184 - val_mae: 1.9614
#
# Epoch 00034: val_mae did not improve from 1.93073
# Epoch 35/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8005 - mse: 6.8005 - mae: 2.0690 - val_loss: 5.8172 - val_mse: 5.8172 - val_mae: 1.9615
#
# Epoch 00035: val_mae did not improve from 1.93073
# Epoch 36/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8966 - mse: 6.8966 - mae: 2.0487 - val_loss: 5.8203 - val_mse: 5.8203 - val_mae: 1.9635
#
# Epoch 00036: val_mae did not improve from 1.93073
# Epoch 37/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.3124 - mse: 7.3124 - mae: 2.1760 - val_loss: 5.8156 - val_mse: 5.8156 - val_mae: 1.9621
#
# Epoch 00037: val_mae did not improve from 1.93073
# Epoch 38/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.1914 - mse: 7.1914 - mae: 2.1424 - val_loss: 5.8142 - val_mse: 5.8142 - val_mae: 1.9621
#
# Epoch 00038: val_mae did not improve from 1.93073
# Epoch 39/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.4531 - mse: 6.4531 - mae: 2.0182 - val_loss: 5.8167 - val_mse: 5.8167 - val_mae: 1.9638
#
# Epoch 00039: val_mae did not improve from 1.93073
# Epoch 40/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5702 - mse: 6.5702 - mae: 2.0682 - val_loss: 5.8126 - val_mse: 5.8126 - val_mae: 1.9626
#
# Epoch 00040: val_mae did not improve from 1.93073
# Epoch 41/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.3251 - mse: 7.3251 - mae: 2.1682 - val_loss: 5.7991 - val_mse: 5.7991 - val_mae: 1.9574
#
# Epoch 00041: val_mae did not improve from 1.93073
# Epoch 42/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9403 - mse: 6.9403 - mae: 2.0560 - val_loss: 5.8003 - val_mse: 5.8003 - val_mae: 1.9586
#
# Epoch 00042: val_mae did not improve from 1.93073
# Epoch 43/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5305 - mse: 6.5305 - mae: 2.0587 - val_loss: 5.7902 - val_mse: 5.7902 - val_mae: 1.9546
#
# Epoch 00043: val_mae did not improve from 1.93073
# Epoch 44/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.3576 - mse: 7.3576 - mae: 2.1991 - val_loss: 5.7912 - val_mse: 5.7912 - val_mae: 1.9558
#
# Epoch 00044: val_mae did not improve from 1.93073
# Epoch 45/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6773 - mse: 6.6773 - mae: 2.1166 - val_loss: 5.7846 - val_mse: 5.7846 - val_mae: 1.9535
#
# Epoch 00045: val_mae did not improve from 1.93073
# Epoch 46/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7121 - mse: 6.7121 - mae: 2.0624 - val_loss: 5.7901 - val_mse: 5.7901 - val_mae: 1.9568
#
# Epoch 00046: val_mae did not improve from 1.93073
# Epoch 47/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7829 - mse: 6.7829 - mae: 2.0520 - val_loss: 5.7888 - val_mse: 5.7888 - val_mae: 1.9569
#
# Epoch 00047: val_mae did not improve from 1.93073
# Epoch 48/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.2816 - mse: 7.2816 - mae: 2.1469 - val_loss: 5.7813 - val_mse: 5.7813 - val_mae: 1.9542
#
# Epoch 00048: val_mae did not improve from 1.93073
# Epoch 49/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 7.6534 - mse: 7.6534 - mae: 2.1162 - val_loss: 5.7873 - val_mse: 5.7873 - val_mae: 1.9576
#
# Epoch 00049: val_mae did not improve from 1.93073
# Epoch 50/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5430 - mse: 6.5430 - mae: 2.0586 - val_loss: 5.7805 - val_mse: 5.7805 - val_mae: 1.9553
#
# Epoch 00050: val_mae did not improve from 1.93073
# Epoch 51/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0085 - mse: 7.0085 - mae: 2.0780 - val_loss: 5.7787 - val_mse: 5.7787 - val_mae: 1.9552
#
# Epoch 00051: val_mae did not improve from 1.93073
# Epoch 52/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0283 - mse: 7.0283 - mae: 2.1354 - val_loss: 5.7725 - val_mse: 5.7725 - val_mae: 1.9532
#
# Epoch 00052: val_mae did not improve from 1.93073
# Epoch 53/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0834 - mse: 7.0834 - mae: 2.1188 - val_loss: 5.7757 - val_mse: 5.7757 - val_mae: 1.9554
#
# Epoch 00053: val_mae did not improve from 1.93073
# Epoch 54/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3896 - mse: 6.3896 - mae: 1.9956 - val_loss: 5.7759 - val_mse: 5.7759 - val_mae: 1.9562
#
# Epoch 00054: val_mae did not improve from 1.93073
# Epoch 55/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8500 - mse: 6.8500 - mae: 2.0679 - val_loss: 5.7705 - val_mse: 5.7705 - val_mae: 1.9547
#
# Epoch 00055: val_mae did not improve from 1.93073
# Epoch 56/1000
# 18/18 [==============================] - 0s 9ms/step - loss: 6.7594 - mse: 6.7594 - mae: 2.0666 - val_loss: 5.7715 - val_mse: 5.7715 - val_mae: 1.9558
#
# Epoch 00056: val_mae did not improve from 1.93073
# Epoch 57/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4724 - mse: 7.4724 - mae: 2.1599 - val_loss: 5.7620 - val_mse: 5.7620 - val_mae: 1.9523
#
# Epoch 00057: val_mae did not improve from 1.93073
# Epoch 58/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0791 - mse: 7.0791 - mae: 2.0776 - val_loss: 5.7516 - val_mse: 5.7516 - val_mae: 1.9484
#
# Epoch 00058: val_mae did not improve from 1.93073
# Epoch 59/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9831 - mse: 6.9831 - mae: 2.1382 - val_loss: 5.7554 - val_mse: 5.7554 - val_mae: 1.9509
#
# Epoch 00059: val_mae did not improve from 1.93073
# Epoch 60/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2845 - mse: 6.2845 - mae: 1.9776 - val_loss: 5.7596 - val_mse: 5.7596 - val_mae: 1.9535
#
# Epoch 00060: val_mae did not improve from 1.93073
# Epoch 61/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.6416 - mse: 6.6416 - mae: 2.0163 - val_loss: 5.7480 - val_mse: 5.7480 - val_mae: 1.9491
#
# Epoch 00061: val_mae did not improve from 1.93073
# Epoch 62/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8239 - mse: 6.8239 - mae: 2.0626 - val_loss: 5.7515 - val_mse: 5.7515 - val_mae: 1.9516
#
# Epoch 00062: val_mae did not improve from 1.93073
# Epoch 63/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.4613 - mse: 6.4613 - mae: 2.0253 - val_loss: 5.7617 - val_mse: 5.7617 - val_mae: 1.9567
#
# Epoch 00063: val_mae did not improve from 1.93073
# Epoch 64/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8859 - mse: 6.8859 - mae: 2.0725 - val_loss: 5.7557 - val_mse: 5.7557 - val_mae: 1.9550
#
# Epoch 00064: val_mae did not improve from 1.93073
# Epoch 65/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.6688 - mse: 7.6688 - mae: 2.1234 - val_loss: 5.7449 - val_mse: 5.7449 - val_mae: 1.9511
#
# Epoch 00065: val_mae did not improve from 1.93073
# Epoch 66/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9026 - mse: 6.9026 - mae: 2.0590 - val_loss: 5.7379 - val_mse: 5.7379 - val_mae: 1.9489
#
# Epoch 00066: val_mae did not improve from 1.93073
# Epoch 67/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3024 - mse: 6.3024 - mae: 2.0020 - val_loss: 5.7328 - val_mse: 5.7328 - val_mae: 1.9473
#
# Epoch 00067: val_mae did not improve from 1.93073
# Epoch 68/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9036 - mse: 6.9036 - mae: 2.0832 - val_loss: 5.7361 - val_mse: 5.7361 - val_mae: 1.9498
#
# Epoch 00068: val_mae did not improve from 1.93073
# Epoch 69/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8013 - mse: 6.8013 - mae: 2.0749 - val_loss: 5.7281 - val_mse: 5.7281 - val_mae: 1.9471
#
# Epoch 00069: val_mae did not improve from 1.93073
# Epoch 70/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.2014 - mse: 7.2014 - mae: 2.1182 - val_loss: 5.7253 - val_mse: 5.7253 - val_mae: 1.9467
#
# Epoch 00070: val_mae did not improve from 1.93073
# Epoch 71/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.5489 - mse: 7.5489 - mae: 2.1585 - val_loss: 5.7169 - val_mse: 5.7169 - val_mae: 1.9438
#
# Epoch 00071: val_mae did not improve from 1.93073
# Epoch 72/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3614 - mse: 6.3614 - mae: 1.9889 - val_loss: 5.7183 - val_mse: 5.7183 - val_mae: 1.9454
#
# Epoch 00072: val_mae did not improve from 1.93073
# Epoch 73/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0690 - mse: 7.0690 - mae: 2.0902 - val_loss: 5.7104 - val_mse: 5.7104 - val_mae: 1.9427
#
# Epoch 00073: val_mae did not improve from 1.93073
# Epoch 74/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7730 - mse: 6.7730 - mae: 2.0625 - val_loss: 5.7062 - val_mse: 5.7062 - val_mae: 1.9417
#
# Epoch 00074: val_mae did not improve from 1.93073
# Epoch 75/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.2855 - mse: 6.2855 - mae: 1.9888 - val_loss: 5.7063 - val_mse: 5.7063 - val_mae: 1.9426
#
# Epoch 00075: val_mae did not improve from 1.93073
# Epoch 76/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3579 - mse: 6.3579 - mae: 1.9944 - val_loss: 5.7071 - val_mse: 5.7071 - val_mae: 1.9440
#
# Epoch 00076: val_mae did not improve from 1.93073
# Epoch 77/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0403 - mse: 7.0403 - mae: 2.0905 - val_loss: 5.7018 - val_mse: 5.7018 - val_mae: 1.9426
#
# Epoch 00077: val_mae did not improve from 1.93073
# Epoch 78/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9407 - mse: 6.9407 - mae: 2.1076 - val_loss: 5.6929 - val_mse: 5.6929 - val_mae: 1.9394
#
# Epoch 00078: val_mae did not improve from 1.93073
# Epoch 79/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0813 - mse: 7.0813 - mae: 2.1351 - val_loss: 5.6910 - val_mse: 5.6910 - val_mae: 1.9395
#
# Epoch 00079: val_mae did not improve from 1.93073
# Epoch 80/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.2590 - mse: 6.2590 - mae: 1.9652 - val_loss: 5.6905 - val_mse: 5.6905 - val_mae: 1.9402
#
# Epoch 00080: val_mae did not improve from 1.93073
# Epoch 81/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6405 - mse: 6.6405 - mae: 2.0542 - val_loss: 5.6852 - val_mse: 5.6852 - val_mae: 1.9387
#
# Epoch 00081: val_mae did not improve from 1.93073
# Epoch 82/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7116 - mse: 6.7116 - mae: 2.0531 - val_loss: 5.6875 - val_mse: 5.6875 - val_mae: 1.9409
#
# Epoch 00082: val_mae did not improve from 1.93073
# Epoch 83/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.1554 - mse: 7.1554 - mae: 2.1283 - val_loss: 5.6831 - val_mse: 5.6831 - val_mae: 1.9398
#
# Epoch 00083: val_mae did not improve from 1.93073
# Epoch 84/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0550 - mse: 7.0550 - mae: 2.1071 - val_loss: 5.6785 - val_mse: 5.6785 - val_mae: 1.9388
#
# Epoch 00084: val_mae did not improve from 1.93073
# Epoch 85/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4453 - mse: 6.4453 - mae: 2.0097 - val_loss: 5.6614 - val_mse: 5.6614 - val_mae: 1.9317
#
# Epoch 00085: val_mae did not improve from 1.93073
# Epoch 86/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 7.3409 - mse: 7.3409 - mae: 2.1305 - val_loss: 5.6645 - val_mse: 5.6645 - val_mae: 1.9343
#
# Epoch 00086: val_mae did not improve from 1.93073
# Epoch 87/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8494 - mse: 6.8494 - mae: 2.1097 - val_loss: 5.6552 - val_mse: 5.6552 - val_mae: 1.9310
#
# Epoch 00087: val_mae did not improve from 1.93073
# Epoch 88/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.4964 - mse: 7.4964 - mae: 2.1662 - val_loss: 5.6629 - val_mse: 5.6629 - val_mae: 1.9357
#
# Epoch 00088: val_mae did not improve from 1.93073
# Epoch 89/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3824 - mse: 6.3824 - mae: 1.9959 - val_loss: 5.6609 - val_mse: 5.6609 - val_mae: 1.9358
#
# Epoch 00089: val_mae did not improve from 1.93073
# Epoch 90/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.3906 - mse: 7.3906 - mae: 2.1081 - val_loss: 5.6576 - val_mse: 5.6576 - val_mae: 1.9354
#
# Epoch 00090: val_mae did not improve from 1.93073
# Epoch 91/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.5279 - mse: 6.5279 - mae: 2.0518 - val_loss: 5.6545 - val_mse: 5.6545 - val_mae: 1.9350
#
# Epoch 00091: val_mae did not improve from 1.93073
# Epoch 92/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0208 - mse: 7.0208 - mae: 2.1230 - val_loss: 5.6456 - val_mse: 5.6456 - val_mae: 1.9320
#
# Epoch 00092: val_mae did not improve from 1.93073
# Epoch 93/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.6106 - mse: 7.6106 - mae: 2.2087 - val_loss: 5.6367 - val_mse: 5.6367 - val_mae: 1.9290
#
# Epoch 00093: val_mae improved from 1.93073 to 1.92905, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 94/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9441 - mse: 6.9441 - mae: 2.0777 - val_loss: 5.6341 - val_mse: 5.6341 - val_mae: 1.9289
#
# Epoch 00094: val_mae improved from 1.92905 to 1.92893, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 95/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2386 - mse: 6.2386 - mae: 1.9623 - val_loss: 5.6333 - val_mse: 5.6333 - val_mae: 1.9297
#
# Epoch 00095: val_mae did not improve from 1.92893
# Epoch 96/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.2334 - mse: 6.2334 - mae: 2.0149 - val_loss: 5.6294 - val_mse: 5.6294 - val_mae: 1.9291
#
# Epoch 00096: val_mae did not improve from 1.92893
# Epoch 97/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0759 - mse: 7.0759 - mae: 2.1096 - val_loss: 5.6357 - val_mse: 5.6357 - val_mae: 1.9331
#
# Epoch 00097: val_mae did not improve from 1.92893
# Epoch 98/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4927 - mse: 6.4927 - mae: 2.0213 - val_loss: 5.6313 - val_mse: 5.6313 - val_mae: 1.9322
#
# Epoch 00098: val_mae did not improve from 1.92893
# Epoch 99/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7828 - mse: 6.7828 - mae: 2.1115 - val_loss: 5.6190 - val_mse: 5.6190 - val_mae: 1.9277
#
# Epoch 00099: val_mae improved from 1.92893 to 1.92773, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 100/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.0133 - mse: 6.0133 - mae: 1.9569 - val_loss: 5.6269 - val_mse: 5.6269 - val_mae: 1.9324
#
# Epoch 00100: val_mae did not improve from 1.92773
# Epoch 101/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2225 - mse: 6.2225 - mae: 2.0068 - val_loss: 5.6148 - val_mse: 5.6148 - val_mae: 1.9281
#
# Epoch 00101: val_mae did not improve from 1.92773
# Epoch 102/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2890 - mse: 7.2890 - mae: 2.1412 - val_loss: 5.6165 - val_mse: 5.6165 - val_mae: 1.9300
#
# Epoch 00102: val_mae did not improve from 1.92773
# Epoch 103/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6913 - mse: 6.6913 - mae: 2.0938 - val_loss: 5.6054 - val_mse: 5.6054 - val_mae: 1.9260
#
# Epoch 00103: val_mae improved from 1.92773 to 1.92596, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 104/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.1666 - mse: 7.1666 - mae: 2.1377 - val_loss: 5.6031 - val_mse: 5.6031 - val_mae: 1.9262
#
# Epoch 00104: val_mae did not improve from 1.92596
# Epoch 105/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9277 - mse: 6.9277 - mae: 2.0751 - val_loss: 5.5947 - val_mse: 5.5947 - val_mae: 1.9235
#
# Epoch 00105: val_mae improved from 1.92596 to 1.92350, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 106/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 7.3844 - mse: 7.3844 - mae: 2.2111 - val_loss: 5.6023 - val_mse: 5.6023 - val_mae: 1.9280
#
# Epoch 00106: val_mae did not improve from 1.92350
# Epoch 107/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0035 - mse: 7.0035 - mae: 2.1392 - val_loss: 5.5883 - val_mse: 5.5883 - val_mae: 1.9229
#
# Epoch 00107: val_mae improved from 1.92350 to 1.92289, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 108/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 6.5537 - mse: 6.5537 - mae: 2.0256 - val_loss: 5.5808 - val_mse: 5.5808 - val_mae: 1.9207
#
# Epoch 00108: val_mae improved from 1.92289 to 1.92065, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 109/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0156 - mse: 7.0156 - mae: 2.1004 - val_loss: 5.5798 - val_mse: 5.5798 - val_mae: 1.9213
#
# Epoch 00109: val_mae did not improve from 1.92065
# Epoch 110/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4631 - mse: 6.4631 - mae: 2.0500 - val_loss: 5.5660 - val_mse: 5.5660 - val_mae: 1.9163
#
# Epoch 00110: val_mae improved from 1.92065 to 1.91632, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 111/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.6415 - mse: 7.6415 - mae: 2.1419 - val_loss: 5.5749 - val_mse: 5.5749 - val_mae: 1.9216
#
# Epoch 00111: val_mae did not improve from 1.91632
# Epoch 112/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9018 - mse: 6.9018 - mae: 2.1076 - val_loss: 5.5610 - val_mse: 5.5610 - val_mae: 1.9163
#
# Epoch 00112: val_mae did not improve from 1.91632
# Epoch 113/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6694 - mse: 6.6694 - mae: 2.0432 - val_loss: 5.5598 - val_mse: 5.5598 - val_mae: 1.9170
#
# Epoch 00113: val_mae did not improve from 1.91632
# Epoch 114/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3000 - mse: 6.3000 - mae: 2.0168 - val_loss: 5.5599 - val_mse: 5.5599 - val_mae: 1.9183
#
# Epoch 00114: val_mae did not improve from 1.91632
# Epoch 115/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6860 - mse: 6.6860 - mae: 2.0694 - val_loss: 5.5586 - val_mse: 5.5586 - val_mae: 1.9188
#
# Epoch 00115: val_mae did not improve from 1.91632
# Epoch 116/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9217 - mse: 6.9217 - mae: 2.0601 - val_loss: 5.5453 - val_mse: 5.5453 - val_mae: 1.9139
#
# Epoch 00116: val_mae improved from 1.91632 to 1.91394, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 117/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.2556 - mse: 7.2556 - mae: 2.1100 - val_loss: 5.5437 - val_mse: 5.5437 - val_mae: 1.9145
#
# Epoch 00117: val_mae did not improve from 1.91394
# Epoch 118/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2496 - mse: 7.2496 - mae: 2.1289 - val_loss: 5.5364 - val_mse: 5.5364 - val_mae: 1.9125
#
# Epoch 00118: val_mae improved from 1.91394 to 1.91249, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 119/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2129 - mse: 6.2129 - mae: 1.9308 - val_loss: 5.5304 - val_mse: 5.5304 - val_mae: 1.9110
#
# Epoch 00119: val_mae improved from 1.91249 to 1.91102, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 120/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.0609 - mse: 6.0609 - mae: 1.9697 - val_loss: 5.5318 - val_mse: 5.5318 - val_mae: 1.9128
#
# Epoch 00120: val_mae did not improve from 1.91102
# Epoch 121/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7646 - mse: 6.7646 - mae: 2.0813 - val_loss: 5.5378 - val_mse: 5.5378 - val_mae: 1.9167
#
# Epoch 00121: val_mae did not improve from 1.91102
# Epoch 122/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 6.7262 - mse: 6.7262 - mae: 2.1020 - val_loss: 5.5192 - val_mse: 5.5192 - val_mae: 1.9099
#
# Epoch 00122: val_mae improved from 1.91102 to 1.90992, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 123/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.1420 - mse: 6.1420 - mae: 1.9787 - val_loss: 5.5196 - val_mse: 5.5196 - val_mae: 1.9112
#
# Epoch 00123: val_mae did not improve from 1.90992
# Epoch 124/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.1773 - mse: 7.1773 - mae: 2.0838 - val_loss: 5.5122 - val_mse: 5.5122 - val_mae: 1.9092
#
# Epoch 00124: val_mae improved from 1.90992 to 1.90916, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 125/1000
# 18/18 [==============================] - 0s 8ms/step - loss: 6.7656 - mse: 6.7656 - mae: 2.0556 - val_loss: 5.5079 - val_mse: 5.5079 - val_mae: 1.9084
#
# Epoch 00125: val_mae improved from 1.90916 to 1.90845, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 126/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6116 - mse: 6.6116 - mae: 2.0285 - val_loss: 5.4962 - val_mse: 5.4962 - val_mae: 1.9044
#
# Epoch 00126: val_mae improved from 1.90845 to 1.90444, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 127/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6093 - mse: 6.6093 - mae: 2.0235 - val_loss: 5.4901 - val_mse: 5.4901 - val_mae: 1.9030
#
# Epoch 00127: val_mae improved from 1.90444 to 1.90301, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 128/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.4357 - mse: 7.4357 - mae: 2.1313 - val_loss: 5.4928 - val_mse: 5.4928 - val_mae: 1.9056
#
# Epoch 00128: val_mae did not improve from 1.90301
# Epoch 129/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0143 - mse: 7.0143 - mae: 2.1211 - val_loss: 5.4897 - val_mse: 5.4897 - val_mae: 1.9055
#
# Epoch 00129: val_mae did not improve from 1.90301
# Epoch 130/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.9211 - mse: 6.9211 - mae: 2.0698 - val_loss: 5.4819 - val_mse: 5.4819 - val_mae: 1.9033
#
# Epoch 00130: val_mae did not improve from 1.90301
# Epoch 131/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8608 - mse: 6.8608 - mae: 2.0957 - val_loss: 5.4933 - val_mse: 5.4933 - val_mae: 1.9093
#
# Epoch 00131: val_mae did not improve from 1.90301
# Epoch 132/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7187 - mse: 6.7187 - mae: 2.1233 - val_loss: 5.4857 - val_mse: 5.4857 - val_mae: 1.9072
#
# Epoch 00132: val_mae did not improve from 1.90301
# Epoch 133/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7996 - mse: 6.7996 - mae: 2.0871 - val_loss: 5.4576 - val_mse: 5.4576 - val_mae: 1.8959
#
# Epoch 00133: val_mae improved from 1.90301 to 1.89592, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 134/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2650 - mse: 6.2650 - mae: 1.9981 - val_loss: 5.4567 - val_mse: 5.4567 - val_mae: 1.8971
#
# Epoch 00134: val_mae did not improve from 1.89592
# Epoch 135/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.3720 - mse: 7.3720 - mae: 2.1788 - val_loss: 5.4581 - val_mse: 5.4581 - val_mae: 1.8991
#
# Epoch 00135: val_mae did not improve from 1.89592
# Epoch 136/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4965 - mse: 6.4965 - mae: 1.9940 - val_loss: 5.4516 - val_mse: 5.4516 - val_mae: 1.8975
#
# Epoch 00136: val_mae did not improve from 1.89592
# Epoch 137/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9800 - mse: 6.9800 - mae: 2.0553 - val_loss: 5.4481 - val_mse: 5.4481 - val_mae: 1.8974
#
# Epoch 00137: val_mae did not improve from 1.89592
# Epoch 138/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.8201 - mse: 6.8201 - mae: 2.1096 - val_loss: 5.4530 - val_mse: 5.4530 - val_mae: 1.9008
#
# Epoch 00138: val_mae did not improve from 1.89592
# Epoch 139/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0418 - mse: 7.0418 - mae: 2.1503 - val_loss: 5.4387 - val_mse: 5.4387 - val_mae: 1.8959
#
# Epoch 00139: val_mae improved from 1.89592 to 1.89591, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 140/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2932 - mse: 6.2932 - mae: 2.0028 - val_loss: 5.4317 - val_mse: 5.4317 - val_mae: 1.8941
#
# Epoch 00140: val_mae improved from 1.89591 to 1.89411, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 141/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 6.5463 - mse: 6.5463 - mae: 2.0720 - val_loss: 5.4388 - val_mse: 5.4388 - val_mae: 1.8984
#
# Epoch 00141: val_mae did not improve from 1.89411
# Epoch 142/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8721 - mse: 6.8721 - mae: 2.0877 - val_loss: 5.4245 - val_mse: 5.4245 - val_mae: 1.8936
#
# Epoch 00142: val_mae improved from 1.89411 to 1.89361, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 143/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3502 - mse: 6.3502 - mae: 2.0348 - val_loss: 5.4169 - val_mse: 5.4169 - val_mae: 1.8916
#
# Epoch 00143: val_mae improved from 1.89361 to 1.89165, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 144/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4427 - mse: 6.4427 - mae: 1.9822 - val_loss: 5.4208 - val_mse: 5.4208 - val_mae: 1.8944
#
# Epoch 00144: val_mae did not improve from 1.89165
# Epoch 145/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.4642 - mse: 6.4642 - mae: 2.0432 - val_loss: 5.4159 - val_mse: 5.4159 - val_mae: 1.8936
#
# Epoch 00145: val_mae did not improve from 1.89165
# Epoch 146/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1427 - mse: 7.1427 - mae: 2.0886 - val_loss: 5.4132 - val_mse: 5.4132 - val_mae: 1.8936
#
# Epoch 00146: val_mae did not improve from 1.89165
# Epoch 147/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8232 - mse: 6.8232 - mae: 2.0592 - val_loss: 5.4031 - val_mse: 5.4031 - val_mae: 1.8905
#
# Epoch 00147: val_mae improved from 1.89165 to 1.89054, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 148/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2408 - mse: 6.2408 - mae: 1.9663 - val_loss: 5.3927 - val_mse: 5.3927 - val_mae: 1.8874
#
# Epoch 00148: val_mae improved from 1.89054 to 1.88743, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 149/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 7.0804 - mse: 7.0804 - mae: 2.0963 - val_loss: 5.3927 - val_mse: 5.3927 - val_mae: 1.8886
#
# Epoch 00149: val_mae did not improve from 1.88743
# Epoch 150/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3552 - mse: 6.3552 - mae: 2.0242 - val_loss: 5.3767 - val_mse: 5.3767 - val_mae: 1.8830
#
# Epoch 00150: val_mae improved from 1.88743 to 1.88297, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 151/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.6190 - mse: 6.6190 - mae: 2.0694 - val_loss: 5.3984 - val_mse: 5.3984 - val_mae: 1.8934
#
# Epoch 00151: val_mae did not improve from 1.88297
# Epoch 152/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4980 - mse: 6.4980 - mae: 2.0609 - val_loss: 5.3759 - val_mse: 5.3759 - val_mae: 1.8855
#
# Epoch 00152: val_mae did not improve from 1.88297
# Epoch 153/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5174 - mse: 6.5174 - mae: 2.0586 - val_loss: 5.3727 - val_mse: 5.3727 - val_mae: 1.8853
#
# Epoch 00153: val_mae did not improve from 1.88297
# Epoch 154/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5475 - mse: 6.5475 - mae: 2.0242 - val_loss: 5.3643 - val_mse: 5.3643 - val_mae: 1.8829
#
# Epoch 00154: val_mae improved from 1.88297 to 1.88292, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 155/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.0168 - mse: 7.0168 - mae: 2.0294 - val_loss: 5.3708 - val_mse: 5.3708 - val_mae: 1.8867
#
# Epoch 00155: val_mae did not improve from 1.88292
# Epoch 156/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.5161 - mse: 6.5161 - mae: 2.0304 - val_loss: 5.3602 - val_mse: 5.3602 - val_mae: 1.8836
#
# Epoch 00156: val_mae did not improve from 1.88292
# Epoch 157/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.2830 - mse: 7.2830 - mae: 2.1111 - val_loss: 5.3510 - val_mse: 5.3510 - val_mae: 1.8810
#
# Epoch 00157: val_mae improved from 1.88292 to 1.88104, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 158/1000
# 18/18 [==============================] - 0s 7ms/step - loss: 6.7398 - mse: 6.7398 - mae: 2.1262 - val_loss: 5.3389 - val_mse: 5.3389 - val_mae: 1.8769
#
# Epoch 00158: val_mae improved from 1.88104 to 1.87694, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 159/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.4963 - mse: 7.4963 - mae: 2.1538 - val_loss: 5.3328 - val_mse: 5.3328 - val_mae: 1.8757
#
# Epoch 00159: val_mae improved from 1.87694 to 1.87569, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 160/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.6856 - mse: 6.6856 - mae: 2.0423 - val_loss: 5.3231 - val_mse: 5.3231 - val_mae: 1.8723
#
# Epoch 00160: val_mae improved from 1.87569 to 1.87234, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 161/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 7.1204 - mse: 7.1204 - mae: 2.0986 - val_loss: 5.3384 - val_mse: 5.3384 - val_mae: 1.8806
#
# Epoch 00161: val_mae did not improve from 1.87234
# Epoch 162/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8934 - mse: 6.8934 - mae: 2.1109 - val_loss: 5.3241 - val_mse: 5.3241 - val_mae: 1.8758
#
# Epoch 00162: val_mae did not improve from 1.87234
# Epoch 163/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.1397 - mse: 7.1397 - mae: 2.1275 - val_loss: 5.3195 - val_mse: 5.3195 - val_mae: 1.8750
#
# Epoch 00163: val_mae did not improve from 1.87234
# Epoch 164/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.9186 - mse: 6.9186 - mae: 2.1078 - val_loss: 5.3151 - val_mse: 5.3151 - val_mae: 1.8744
#
# Epoch 00164: val_mae did not improve from 1.87234
# Epoch 165/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0069 - mse: 7.0069 - mae: 2.0938 - val_loss: 5.3102 - val_mse: 5.3102 - val_mae: 1.8735
#
# Epoch 00165: val_mae did not improve from 1.87234
# Epoch 166/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.0934 - mse: 7.0934 - mae: 2.0736 - val_loss: 5.3055 - val_mse: 5.3055 - val_mae: 1.8727
#
# Epoch 00166: val_mae did not improve from 1.87234
# Epoch 167/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3528 - mse: 6.3528 - mae: 2.0217 - val_loss: 5.3012 - val_mse: 5.3012 - val_mae: 1.8721
#
# Epoch 00167: val_mae improved from 1.87234 to 1.87206, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 168/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.8440 - mse: 6.8440 - mae: 2.0412 - val_loss: 5.2931 - val_mse: 5.2931 - val_mae: 1.8699
#
# Epoch 00168: val_mae improved from 1.87206 to 1.86986, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 169/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 5.9193 - mse: 5.9193 - mae: 1.9395 - val_loss: 5.2840 - val_mse: 5.2840 - val_mae: 1.8671
#
# Epoch 00169: val_mae improved from 1.86986 to 1.86712, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 170/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.6014 - mse: 6.6014 - mae: 2.0550 - val_loss: 5.2933 - val_mse: 5.2933 - val_mae: 1.8726
#
# Epoch 00170: val_mae did not improve from 1.86712
# Epoch 171/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.7769 - mse: 6.7769 - mae: 2.0321 - val_loss: 5.2919 - val_mse: 5.2919 - val_mae: 1.8732
#
# Epoch 00171: val_mae did not improve from 1.86712
# Epoch 172/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3550 - mse: 6.3550 - mae: 2.0166 - val_loss: 5.2904 - val_mse: 5.2904 - val_mae: 1.8737
#
# Epoch 00172: val_mae did not improve from 1.86712
# Epoch 173/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7812 - mse: 6.7812 - mae: 2.0722 - val_loss: 5.2949 - val_mse: 5.2949 - val_mae: 1.8767
#
# Epoch 00173: val_mae did not improve from 1.86712
# Epoch 174/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.1887 - mse: 6.1887 - mae: 1.9767 - val_loss: 5.2730 - val_mse: 5.2730 - val_mae: 1.8690
#
# Epoch 00174: val_mae did not improve from 1.86712
# Epoch 175/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.0462 - mse: 6.0462 - mae: 1.9717 - val_loss: 5.2562 - val_mse: 5.2562 - val_mae: 1.8628
#
# Epoch 00175: val_mae improved from 1.86712 to 1.86282, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 176/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3367 - mse: 6.3367 - mae: 1.9923 - val_loss: 5.2601 - val_mse: 5.2601 - val_mae: 1.8659
#
# Epoch 00176: val_mae did not improve from 1.86282
# Epoch 177/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.3882 - mse: 6.3882 - mae: 2.0390 - val_loss: 5.2669 - val_mse: 5.2669 - val_mae: 1.8699
#
# Epoch 00177: val_mae did not improve from 1.86282
# Epoch 178/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.6048 - mse: 6.6048 - mae: 2.0342 - val_loss: 5.2699 - val_mse: 5.2699 - val_mae: 1.8723
#
# Epoch 00178: val_mae did not improve from 1.86282
# Epoch 179/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 7.1293 - mse: 7.1293 - mae: 2.1066 - val_loss: 5.2403 - val_mse: 5.2403 - val_mae: 1.8613
#
# Epoch 00179: val_mae improved from 1.86282 to 1.86129, saving model to /home/m-marouni/Documents/CE-901/Heathrow/best_weights
# INFO:tensorflow:Assets written to: /home/m-marouni/Documents/CE-901/Heathrow/best_weights/assets
# Epoch 180/1000
# ...
#
# Epoch 00741: val_mae did not improve from 1.71192
# Epoch 742/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2803 - mse: 6.2803 - mae: 1.9966 - val_loss: 4.5304 - val_mse: 4.5304 - val_mae: 1.7160
#
# Epoch 00742: val_mae did not improve from 1.71192
# Epoch 743/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.9581 - mse: 5.9581 - mae: 1.9342 - val_loss: 4.5319 - val_mse: 4.5319 - val_mae: 1.7174
#
# Epoch 00743: val_mae did not improve from 1.71192
# Epoch 744/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.3936 - mse: 6.3936 - mae: 1.9993 - val_loss: 4.5306 - val_mse: 4.5306 - val_mae: 1.7161
#
# Epoch 00744: val_mae did not improve from 1.71192
# Epoch 745/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.2368 - mse: 6.2368 - mae: 1.9852 - val_loss: 4.5298 - val_mse: 4.5298 - val_mae: 1.7156
#
# Epoch 00745: val_mae did not improve from 1.71192
# Epoch 746/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.3342 - mse: 5.3342 - mae: 1.8118 - val_loss: 4.5291 - val_mse: 4.5291 - val_mae: 1.7153
#
# Epoch 00746: val_mae did not improve from 1.71192
# Epoch 747/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2638 - mse: 6.2638 - mae: 1.9458 - val_loss: 4.5322 - val_mse: 4.5322 - val_mae: 1.7179
#
# Epoch 00747: val_mae did not improve from 1.71192
# Epoch 748/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.8468 - mse: 5.8468 - mae: 1.9042 - val_loss: 4.5363 - val_mse: 4.5363 - val_mae: 1.7207
#
# Epoch 00748: val_mae did not improve from 1.71192
# Epoch 749/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.1296 - mse: 6.1296 - mae: 1.9464 - val_loss: 4.5327 - val_mse: 4.5327 - val_mae: 1.7183
#
# Epoch 00749: val_mae did not improve from 1.71192
# Epoch 750/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.9963 - mse: 5.9963 - mae: 1.9565 - val_loss: 4.5352 - val_mse: 4.5352 - val_mae: 1.7201
#
# Epoch 00750: val_mae did not improve from 1.71192
# Epoch 751/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.5764 - mse: 5.5764 - mae: 1.8545 - val_loss: 4.5285 - val_mse: 4.5285 - val_mae: 1.7149
#
# Epoch 00751: val_mae did not improve from 1.71192
# Epoch 752/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.6150 - mse: 5.6150 - mae: 1.8976 - val_loss: 4.5322 - val_mse: 4.5322 - val_mae: 1.7181
#
# Epoch 00752: val_mae did not improve from 1.71192
# Epoch 753/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.7837 - mse: 5.7837 - mae: 1.8968 - val_loss: 4.5360 - val_mse: 4.5360 - val_mae: 1.7205
#
# Epoch 00753: val_mae did not improve from 1.71192
# Epoch 754/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.7587 - mse: 5.7587 - mae: 1.9208 - val_loss: 4.5336 - val_mse: 4.5336 - val_mae: 1.7190
#
# Epoch 00754: val_mae did not improve from 1.71192
# Epoch 755/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.9653 - mse: 5.9653 - mae: 1.9034 - val_loss: 4.5301 - val_mse: 4.5301 - val_mae: 1.7164
#
# Epoch 00755: val_mae did not improve from 1.71192
# Epoch 756/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.1514 - mse: 6.1514 - mae: 1.9824 - val_loss: 4.5357 - val_mse: 4.5357 - val_mae: 1.7203
#
# Epoch 00756: val_mae did not improve from 1.71192
# Epoch 757/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2176 - mse: 6.2176 - mae: 1.9886 - val_loss: 4.5309 - val_mse: 4.5309 - val_mae: 1.7169
#
# Epoch 00757: val_mae did not improve from 1.71192
# Epoch 758/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 5.8052 - mse: 5.8052 - mae: 1.8836 - val_loss: 4.5272 - val_mse: 4.5272 - val_mae: 1.7127
#
# Epoch 00758: val_mae did not improve from 1.71192
# Epoch 759/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 5.3863 - mse: 5.3863 - mae: 1.8488 - val_loss: 4.5362 - val_mse: 4.5362 - val_mae: 1.7204
#
# Epoch 00759: val_mae did not improve from 1.71192
# Epoch 760/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.7094 - mse: 5.7094 - mae: 1.8613 - val_loss: 4.5326 - val_mse: 4.5326 - val_mae: 1.7181
#
# Epoch 00760: val_mae did not improve from 1.71192
# Epoch 761/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.8630 - mse: 5.8630 - mae: 1.8897 - val_loss: 4.5405 - val_mse: 4.5405 - val_mae: 1.7232
#
# Epoch 00761: val_mae did not improve from 1.71192
# Epoch 762/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3047 - mse: 6.3047 - mae: 1.9387 - val_loss: 4.5359 - val_mse: 4.5359 - val_mae: 1.7203
#
# Epoch 00762: val_mae did not improve from 1.71192
# Epoch 763/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.9458 - mse: 5.9458 - mae: 1.9626 - val_loss: 4.5425 - val_mse: 4.5425 - val_mae: 1.7245
#
# Epoch 00763: val_mae did not improve from 1.71192
# Epoch 764/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 5.3355 - mse: 5.3355 - mae: 1.8561 - val_loss: 4.5369 - val_mse: 4.5369 - val_mae: 1.7209
#
# Epoch 00764: val_mae did not improve from 1.71192
# Epoch 765/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 6.4555 - mse: 6.4555 - mae: 2.0326 - val_loss: 4.5422 - val_mse: 4.5422 - val_mae: 1.7244
#
# Epoch 00765: val_mae did not improve from 1.71192
# Epoch 766/1000
# 18/18 [==============================] - 0s 6ms/step - loss: 5.8280 - mse: 5.8280 - mae: 1.9491 - val_loss: 4.5342 - val_mse: 4.5342 - val_mae: 1.7192
#
# Epoch 00766: val_mae did not improve from 1.71192
# Epoch 767/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.4304 - mse: 5.4304 - mae: 1.8531 - val_loss: 4.5385 - val_mse: 4.5385 - val_mae: 1.7221
#
# Epoch 00767: val_mae did not improve from 1.71192
# Epoch 768/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.5868 - mse: 6.5868 - mae: 2.0189 - val_loss: 4.5368 - val_mse: 4.5368 - val_mae: 1.7210
#
# Epoch 00768: val_mae did not improve from 1.71192
# Epoch 769/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.1317 - mse: 6.1317 - mae: 1.9631 - val_loss: 4.5390 - val_mse: 4.5390 - val_mae: 1.7223
#
# Epoch 00769: val_mae did not improve from 1.71192
# Epoch 770/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.7369 - mse: 5.7369 - mae: 1.8689 - val_loss: 4.5370 - val_mse: 4.5370 - val_mae: 1.7210
#
# Epoch 00770: val_mae did not improve from 1.71192
# Epoch 771/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.3788 - mse: 6.3788 - mae: 2.0097 - val_loss: 4.5362 - val_mse: 4.5362 - val_mae: 1.7205
#
# Epoch 00771: val_mae did not improve from 1.71192
# Epoch 772/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.9295 - mse: 5.9295 - mae: 1.8917 - val_loss: 4.5381 - val_mse: 4.5381 - val_mae: 1.7218
#
# Epoch 00772: val_mae did not improve from 1.71192
# Epoch 773/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.6919 - mse: 5.6919 - mae: 1.8649 - val_loss: 4.5332 - val_mse: 4.5332 - val_mae: 1.7186
#
# Epoch 00773: val_mae did not improve from 1.71192
# Epoch 774/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.0747 - mse: 6.0747 - mae: 1.9705 - val_loss: 4.5315 - val_mse: 4.5315 - val_mae: 1.7175
#
# Epoch 00774: val_mae did not improve from 1.71192
# Epoch 775/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.8770 - mse: 5.8770 - mae: 1.9368 - val_loss: 4.5325 - val_mse: 4.5325 - val_mae: 1.7183
#
# Epoch 00775: val_mae did not improve from 1.71192
# Epoch 776/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.8053 - mse: 5.8053 - mae: 1.8768 - val_loss: 4.5312 - val_mse: 4.5312 - val_mae: 1.7173
#
# Epoch 00776: val_mae did not improve from 1.71192
# Epoch 777/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.8540 - mse: 5.8540 - mae: 1.9014 - val_loss: 4.5397 - val_mse: 4.5397 - val_mae: 1.7230
#
# Epoch 00777: val_mae did not improve from 1.71192
# Epoch 778/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2364 - mse: 6.2364 - mae: 1.9911 - val_loss: 4.5381 - val_mse: 4.5381 - val_mae: 1.7219
#
# Epoch 00778: val_mae did not improve from 1.71192
# Epoch 779/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.7182 - mse: 5.7182 - mae: 1.9061 - val_loss: 4.5334 - val_mse: 4.5334 - val_mae: 1.7187
#
# Epoch 00779: val_mae did not improve from 1.71192
# Epoch 780/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.7538 - mse: 6.7538 - mae: 2.0429 - val_loss: 4.5382 - val_mse: 4.5382 - val_mae: 1.7221
#
# Epoch 00780: val_mae did not improve from 1.71192
# Epoch 781/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.0283 - mse: 6.0283 - mae: 1.9373 - val_loss: 4.5335 - val_mse: 4.5335 - val_mae: 1.7191
#
# Epoch 00781: val_mae did not improve from 1.71192
# Epoch 782/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2969 - mse: 6.2969 - mae: 2.0036 - val_loss: 4.5376 - val_mse: 4.5376 - val_mae: 1.7218
#
# Epoch 00782: val_mae did not improve from 1.71192
# Epoch 783/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.4446 - mse: 5.4446 - mae: 1.8675 - val_loss: 4.5282 - val_mse: 4.5282 - val_mae: 1.7150
#
# Epoch 00783: val_mae did not improve from 1.71192
# Epoch 784/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.5128 - mse: 6.5128 - mae: 1.9712 - val_loss: 4.5354 - val_mse: 4.5354 - val_mae: 1.7205
#
# Epoch 00784: val_mae did not improve from 1.71192
# Epoch 785/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4907 - mse: 6.4907 - mae: 2.0339 - val_loss: 4.5384 - val_mse: 4.5384 - val_mae: 1.7224
#
# Epoch 00785: val_mae did not improve from 1.71192
# Epoch 786/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.4773 - mse: 6.4773 - mae: 2.0016 - val_loss: 4.5303 - val_mse: 4.5303 - val_mae: 1.7171
#
# Epoch 00786: val_mae did not improve from 1.71192
# Epoch 787/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.6905 - mse: 5.6905 - mae: 1.8788 - val_loss: 4.5331 - val_mse: 4.5331 - val_mae: 1.7190
#
# Epoch 00787: val_mae did not improve from 1.71192
# Epoch 788/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.3539 - mse: 5.3539 - mae: 1.8116 - val_loss: 4.5321 - val_mse: 4.5321 - val_mae: 1.7184
#
# Epoch 00788: val_mae did not improve from 1.71192
# Epoch 789/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.8631 - mse: 5.8631 - mae: 1.9191 - val_loss: 4.5362 - val_mse: 4.5362 - val_mae: 1.7210
#
# Epoch 00789: val_mae did not improve from 1.71192
# Epoch 790/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.1896 - mse: 6.1896 - mae: 1.9432 - val_loss: 4.5415 - val_mse: 4.5415 - val_mae: 1.7245
#
# Epoch 00790: val_mae did not improve from 1.71192
# Epoch 791/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.6690 - mse: 5.6690 - mae: 1.8918 - val_loss: 4.5366 - val_mse: 4.5366 - val_mae: 1.7215
#
# Epoch 00791: val_mae did not improve from 1.71192
# Epoch 792/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.8222 - mse: 5.8222 - mae: 1.9285 - val_loss: 4.5370 - val_mse: 4.5370 - val_mae: 1.7218
#
# Epoch 00792: val_mae did not improve from 1.71192
# Epoch 793/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.4940 - mse: 5.4940 - mae: 1.8479 - val_loss: 4.5296 - val_mse: 4.5296 - val_mae: 1.7166
#
# Epoch 00793: val_mae did not improve from 1.71192
# Epoch 794/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.6690 - mse: 5.6690 - mae: 1.8869 - val_loss: 4.5309 - val_mse: 4.5309 - val_mae: 1.7175
#
# Epoch 00794: val_mae did not improve from 1.71192
# Epoch 795/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.1831 - mse: 6.1831 - mae: 1.8903 - val_loss: 4.5369 - val_mse: 4.5369 - val_mae: 1.7215
#
# Epoch 00795: val_mae did not improve from 1.71192
# Epoch 796/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.2681 - mse: 6.2681 - mae: 2.0295 - val_loss: 4.5347 - val_mse: 4.5347 - val_mae: 1.7200
#
# Epoch 00796: val_mae did not improve from 1.71192
# Epoch 797/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.3302 - mse: 6.3302 - mae: 1.9758 - val_loss: 4.5363 - val_mse: 4.5363 - val_mae: 1.7211
#
# Epoch 00797: val_mae did not improve from 1.71192
# Epoch 798/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.4970 - mse: 5.4970 - mae: 1.9120 - val_loss: 4.5361 - val_mse: 4.5361 - val_mae: 1.7209
#
# Epoch 00798: val_mae did not improve from 1.71192
# Epoch 799/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2855 - mse: 6.2855 - mae: 1.9677 - val_loss: 4.5373 - val_mse: 4.5373 - val_mae: 1.7217
#
# Epoch 00799: val_mae did not improve from 1.71192
# Epoch 800/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.4770 - mse: 5.4770 - mae: 1.8421 - val_loss: 4.5377 - val_mse: 4.5377 - val_mae: 1.7220
#
# Epoch 00800: val_mae did not improve from 1.71192
# Epoch 801/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.5282 - mse: 5.5282 - mae: 1.8422 - val_loss: 4.5355 - val_mse: 4.5355 - val_mae: 1.7207
#
# Epoch 00801: val_mae did not improve from 1.71192
# Epoch 802/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.6955 - mse: 5.6955 - mae: 1.9112 - val_loss: 4.5308 - val_mse: 4.5308 - val_mae: 1.7175
#
# Epoch 00802: val_mae did not improve from 1.71192
# Epoch 803/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.9974 - mse: 5.9974 - mae: 1.9581 - val_loss: 4.5363 - val_mse: 4.5363 - val_mae: 1.7213
#
# Epoch 00803: val_mae did not improve from 1.71192
# Epoch 804/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.8789 - mse: 5.8789 - mae: 1.8998 - val_loss: 4.5319 - val_mse: 4.5319 - val_mae: 1.7183
#
# Epoch 00804: val_mae did not improve from 1.71192
# Epoch 805/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.2143 - mse: 6.2143 - mae: 1.9328 - val_loss: 4.5312 - val_mse: 4.5312 - val_mae: 1.7179
#
# Epoch 00805: val_mae did not improve from 1.71192
# Epoch 806/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.9822 - mse: 5.9822 - mae: 1.9001 - val_loss: 4.5306 - val_mse: 4.5306 - val_mae: 1.7176
#
# Epoch 00806: val_mae did not improve from 1.71192
# Epoch 807/1000
# 18/18 [==============================] - 0s 5ms/step - loss: 6.1916 - mse: 6.1916 - mae: 1.9340 - val_loss: 4.5348 - val_mse: 4.5348 - val_mae: 1.7202
#
# Epoch 00807: val_mae did not improve from 1.71192
# Epoch 808/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.8033 - mse: 6.8033 - mae: 2.0569 - val_loss: 4.5389 - val_mse: 4.5389 - val_mae: 1.7229
#
# Epoch 00808: val_mae did not improve from 1.71192
# Epoch 809/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 5.6427 - mse: 5.6427 - mae: 1.8687 - val_loss: 4.5334 - val_mse: 4.5334 - val_mae: 1.7193
#
# Epoch 00809: val_mae did not improve from 1.71192
# Epoch 810/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 6.7707 - mse: 6.7707 - mae: 1.9969 - val_loss: 4.5282 - val_mse: 4.5282 - val_mae: 1.7152
#
# Epoch 00810: val_mae did not improve from 1.71192
# Epoch 811/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.1015 - mse: 6.1015 - mae: 1.9811 - val_loss: 4.5259 - val_mse: 4.5259 - val_mae: 1.7121
#
# Epoch 00811: val_mae did not improve from 1.71192
# Epoch 812/1000
# 18/18 [==============================] - 0s 4ms/step - loss: 6.0600 - mse: 6.0600 - mae: 1.9420 - val_loss: 4.5283 - val_mse: 4.5283 - val_mae: 1.7149
#
# Epoch 00812: val_mae did not improve from 1.71192
# Epoch 813/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.8783 - mse: 5.8783 - mae: 1.9150 - val_loss: 4.5308 - val_mse: 4.5308 - val_mae: 1.7171
#
# Epoch 00813: val_mae did not improve from 1.71192
# Epoch 814/1000
# 18/18 [==============================] - 0s 3ms/step - loss: 5.7325 - mse: 5.7325 - mae: 1.8830 - val_loss: 4.5337 - val_mse: 4.5337 - val_mae: 1.7192
#
# Epoch 00814: val_mae did not improve from 1.71192
# Epoch 00814: early stopping

# %% [markdown]
# ## The minimum error reached after 1000 epochs is VAL_MAE=1.455, MSE=3.523

# %% [markdown]
# ## 5.4. Evalution metrics plots

# %%
def show_info(model, X, y, log, weights = None):
    '''
    Show metrics about the evaluation model and plots about loss, rmse and rmspe
    '''
    if (log != None):
        # summarize history for loss
        plt.figure(figsize=(14,10))
        plt.plot(log.history['loss'])
        plt.plot(log.history['val_loss'])
        plt.title('Model Loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

        # summarize history for MAE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mae'])
        plt.plot(log.history['val_mae'])
        plt.title('Model MAE')
        plt.ylabel('MAE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')

         # summarize history for MSE
        plt.figure(figsize=(14,10))
        plt.plot(log.history['mse'])
        plt.plot(log.history['val_mse'])
        plt.title('Model MSE')
        plt.ylabel('MSE')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
        print('\n')
    if (weights != None):
        model.load_weights(weights)
    
    predictions = model.predict(X, verbose=1)

    mse = mean_squared_error(y, predictions)
    mae= mean_absolute_error(y, predictions)

# %%
show_info(model, x_test, y_test, log, weights='/home/m-marouni/Documents/CE-901/Heathrow/best_weights')
# Out:
# 7/7 [==============================] - 0s 1ms/step

# %% [markdown]
# # 6. Test on unseen data
# ## Data was taken from john lennon airport in liverpool
# ## The model will predict wind speed for 5 days

# %% [markdown]
# ## 6.1. Test dataframe first sight

# %%
df_test=pd.read_excel('liverpool-Test-Data.xlsx')
df_test.head()
df_test.tail()
# Out:
#    Dew point  Wind Speed  Pressure  Pressure Gradient
# 0       16.6           5      1014                 -2
# 1       16.6           4      1012                 -6
# 2       18.0           4      1006                 -5
# 3       17.0           5      1001                 -3
# 4       17.0           8       998                 -3
#    Dew point  Wind Speed  Pressure  Pressure Gradient
# 0       16.6           5      1014                 -2
# 1       16.6           4      1012                 -6
# 2       18.0           4      1006                 -5
# 3       17.0           5      1001                 -3
# 4       17.0           8       998                 -3

# %% [markdown]
# ## 6.2. Divide the features into inputs and output

# %%
X2 = df_test.drop(['Wind Speed'], axis=1)
#Assign the Target column as the output 
Y2 = df_test['Wind Speed']

# %% [markdown]
# ## 6.3. Data normalization

# %%
X2_norm=(X2-X2.min())/(X2.max()-X2.min())
X2_norm
# Out:
#    Dew point  Pressure  Pressure Gradient
# 0   0.000000    1.0000               1.00
# 1   0.000000    0.8750               0.00
# 2   1.000000    0.5000               0.25
# 3   0.285714    0.1875               0.75
# 4   0.285714    0.0000               0.75

# %% [markdown]
# ## 6.4. Predict using the trained model

# %%
new_predictions=model.predict(X2_norm)

# %% [markdown]
# ## 6.4.1. Model predictions

# %%
new_predictions
# Out:
# array([[4.3627157],
#        [3.985342 ],
#        [5.669977 ],
#        [8.324569 ],
#        [9.374418 ]], dtype=float32)

# %% [markdown]
# ## 6.5. Evaluation metrics

# %%
mean_absolute_error(Y2, new_predictions)
# Out:
# 1.4041812896728516

# %%
mean_squared_error(Y2, new_predictions)
# Out:
# 3.227390566040049

# %% [markdown]
# ## Predictions shows an MAE= 1.40 and MSE= 3.22
