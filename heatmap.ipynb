# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
df=pd.read_excel('data.xlsx')
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  Wind Direction
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0             128
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4             188
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8             265
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7             248
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4             224

# %%
df['Year']  = df['Date'].apply(lambda x: int(str(x)[:4]))
df['Month'] = df['Date'].apply(lambda x: int(str(x)[5:7]))
df['Day']=df['Date'].apply(lambda x: int(str(x)[8:10]))
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Year  Month  Day
# 0             128  2020      1    1
# 1             188  2020      1    2
# 2             265  2020      1    3
# 3             248  2020      1    4
# 4             224  2020      1    5

# %%
del df['Date']

# %%
plt.figure(figsize = (16,5))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':25}, pad=10);

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
df=pd.read_excel('data.xlsx')
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad
# 0             128             -8
# 1             188              0
# 2             265             11
# 3             248             -1
# 4             224            -11

# %%
df['Year']  = df['Date'].apply(lambda x: int(str(x)[:4]))
df['Month'] = df['Date'].apply(lambda x: int(str(x)[5:7]))
df['Day']=df['Date'].apply(lambda x: int(str(x)[8:10]))
df.head()
# Out:
#          Date  Temp  Dew Point  Humidity  Wind Speed  Pressure  \
# 0  2020-01-01   5.7        4.8      94.4        2.47    1029.0
# 1  2020-01-02   9.3        8.2      92.5        7.42    1021.4
# 2  2020-01-03   8.2        6.8      91.4        6.81    1021.8
# 3  2020-01-04   5.6        3.6      87.2        3.94    1033.7
# 4  2020-01-05   7.8        6.1      89.2        3.33    1033.4
#
#    Wind Direction  Pressure Grad  Year  Month  Day
# 0             128             -8  2020      1    1
# 1             188              0  2020      1    2
# 2             265             11  2020      1    3
# 3             248             -1  2020      1    4
# 4             224            -11  2020      1    5

# %%
del df['Date']

# %%
plt.figure(figsize = (16,5))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':25}, pad=10);
